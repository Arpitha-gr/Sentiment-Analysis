# %% [markdown]
# # Analysis of the scrapped content

# %% [markdown]
# ### Installing packages

# %% [markdown]
# !pip install spacy

# %% [markdown]
# nltk.download('punkt')

# %% [markdown]
# nltk.download('wordnet')

# %% [markdown]
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz

# %% [markdown]
# !pip install --upgrade "ibm-watson>=5.1.0"

# %% [markdown]
# !pip install chromedriver-autoinstaller

# %% [markdown]
# !pip install selenium

# %% [markdown]
# !pip install python-dotenv

# %% [markdown]
# ### Downloading the dataset from online

# %% [markdown]
# from Scweet.scweet import scrap
# from Scweet.user import get_user_information, get_users_following, get_users_followers
# data = scrap(words=['Fitbit Sense'], start_date="2021-01-01", max_date="2021-06-01", from_account = None,interval=1,
#       headless=True, display_type="Top", save_images=False,
#              resume=False, filter_replies=True, proximity=True)
# data.head()

# %% [markdown]
# ### Importing packages

# %%
import nltk
import json
from nltk import sent_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
import pandas as pd
import numpy as np
import re  
import spacy
from ibm_watson import ToneAnalyzerV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %% [markdown]
# ### Error in spacy.load('en_core_web_sm')

# %% [markdown]
# Could not read config.cfg from C:\Users\arpit\Anaconda3\lib\site-packages\en_core_web_sm\en_core_web_sm-2.2.0\config.cfg

# %% [markdown]
# ### Solution: Open Anaconda prompt and type the line given below

# %% [markdown]
# python -m spacy download en_core_web_sm

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# Reading Scrapped Data from the file

# %% [markdown]
# ### Reading CSV file

# %%
#pd.set_option('display.max_rows',None)

# %%
df=pd.read_csv('New_Fitbit.csv')

# %%
df
# Out:
#               UserScreenName          UserName                 Timestamp  \
# 0            Sandra Lafuente      @sandritalaf  2021-01-01T22:19:32.000Z
# 1     SheddingMoreThanPounds       @ThanPounds  2021-01-01T18:38:48.000Z
# 2              Cynthia Weirr        @Ngochiana  2021-01-01T14:34:59.000Z
# 3                    Heather  @Heather20358236  2021-01-01T04:08:29.000Z
# 4           のちお9割はｱｲｽで出来ています      @bow_tie_cat  2021-01-01T19:44:17.000Z
# ...                      ...               ...                       ...
# 1210              sevenones1       @sevenones1  2021-05-31T14:54:14.000Z
# 1211   The Student Tech Blog  @TheStudentTech1  2021-05-31T11:05:43.000Z
# 1212         Competitions.ie  @competitions_ie  2021-05-31T12:38:50.000Z
# 1213       Chance and Choice     @kareikitchen  2021-05-31T04:19:25.000Z
# 1214               Fitbit_DE        @Fitbit_DE  2021-05-31T08:13:06.000Z
#
#                                                    Text  \
# 0                          2021 Sin excusas#FitbitSENSE
# 1     Upped my steps today with a lovely walk by the...
# 2     Fitbit Sense drops to lowest price yet in the ...
# 3     My fitbit sense worked at first with phone cal...
# 4     やっぱりfitbit senseが無難かなー。夫が隣でもうオーダーしようとしてるから慌てて止...
# ...                                                 ...
# 1210  Package #1 - 1100 Fitbit Clockfaces $20 - for ...
# 1211  Get a Fitbit Sense for under £250 (Global)\n.\...
# 1212  Win a top of the line smartwatch, the Fitbit S...
# 1213  fitbit sense フィットビット センス 国内正規品 Carbon Graphite...
# 1214  Dein innerer Akku ist fast leer? Schließe für ...
#
#                                           Embedded_text         Emojis  \
# 0                                                   NaN              👟
# 1                                                   NaN            NaN
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4                                                   NaN  🍦 😅 🤑 💸 💸 💸 💸
# ...                                                 ...            ...
# 1210  Become healthy\nBecome a healthier, happier yo...            NaN
# 1211  Fitbit Sense Advanced Smartwatch with Tools fo...            NaN
# 1212  Win a top of the line smartwatch, the Fitbit S...        👉 💚 💚 💚
# 1213  【楽天市場】(あす楽)fitbit sense フィットビット センス 国内正規品 Carb...            NaN
# 1214                                     0:07\n88 views              🧘
#
#      Comments Likes Retweets  \
# 0           3   NaN        6
# 1         NaN   NaN        1
# 2         NaN   NaN      NaN
# 3         NaN   NaN      NaN
# 4         NaN   NaN        1
# ...       ...   ...      ...
# 1210      NaN   NaN      NaN
# 1211      NaN   NaN      NaN
# 1212      NaN   NaN      NaN
# 1213      NaN     5        6
# 1214        1     1        3
#
#                                              Image link  \
# 0     ['https://pbs.twimg.com/media/Eqre86CXIAACdYI?...
# 1     ['https://pbs.twimg.com/media/EqqsbPeXcAAcbq5?...
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1210  ['https://pbs.twimg.com/card_img/1404473934666...
# 1211  ['https://pbs.twimg.com/card_img/1404589424390...
# 1212  ['https://pbs.twimg.com/card_img/1404630448748...
# 1213  ['https://pbs.twimg.com/card_img/1404382354072...
# 1214  ['https://pbs.twimg.com/ext_tw_video_thumb/139...
#
#                                               Tweet URL
# 0     https://twitter.com/sandritalaf/status/1345132...
# 1     https://twitter.com/ThanPounds/status/13450770...
# 2     https://twitter.com/Ngochiana/status/134501567...
# 3     https://twitter.com/Heather20358236/status/134...
# 4     https://twitter.com/bow_tie_cat/status/1345093...
# ...                                                 ...
# 1210  https://twitter.com/sevenones1/status/13993786...
# 1211  https://twitter.com/TheStudentTech1/status/139...
# 1212  https://twitter.com/competitions_ie/status/139...
# 1213  https://twitter.com/kareikitchen/status/139921...
# 1214  https://twitter.com/Fitbit_DE/status/139927774...
#
# [1215 rows x 11 columns]

# %%
df_text=df['Text']
df_text
# Out:
# 0                            2021 Sin excusas#FitbitSENSE
# 1       Upped my steps today with a lovely walk by the...
# 2       Fitbit Sense drops to lowest price yet in the ...
# 3       My fitbit sense worked at first with phone cal...
# 4       やっぱりfitbit senseが無難かなー。夫が隣でもうオーダーしようとしてるから慌てて止...
#                               ...
# 1210    Package #1 - 1100 Fitbit Clockfaces $20 - for ...
# 1211    Get a Fitbit Sense for under £250 (Global)\n.\...
# 1212    Win a top of the line smartwatch, the Fitbit S...
# 1213    fitbit sense フィットビット センス 国内正規品 Carbon Graphite...
# 1214    Dein innerer Akku ist fast leer? Schließe für ...
# Name: Text, Length: 1215, dtype: object

# %%
df_date=df['Timestamp']
for i in range(0,len(df_date)):
    print(df_date.loc[i][0:10])
# Out:
# 2021-01-01
# 2021-01-01
# 2021-01-01
# 2021-01-01
# 2021-01-01
# 2021-01-01
# 2021-01-01
# 2021-01-01
# 2021-01-01
# 2021-01-02
# 2021-01-02
# 2021-01-02
# 2021-01-02
# 2021-01-02
# 2021-01-02
# 2021-01-02
# 2021-01-02
# 2021-01-02
# 2021-01-02
# 2021-01-02
# 2021-01-02
# 2021-01-02
# 2021-01-02
# 2021-01-02
# 2021-01-02
# 2021-01-03
# 2021-01-03
# 2021-01-03
# 2021-01-03
# 2021-01-03
# 2021-01-03
# 2021-01-03
# 2021-01-04
# 2021-01-04
# 2021-01-04
# 2021-01-04
# 2021-01-04
# 2021-01-04
# 2021-01-04
# 2021-01-04
# 2021-01-04
# 2021-01-05
# 2021-01-05
# 2021-01-05
# 2021-01-05
# 2021-01-05
# 2021-01-05
# 2021-01-05
# 2021-01-05
# 2021-01-05
# 2021-01-05
# 2021-01-05
# 2021-01-05
# 2021-01-05
# 2021-01-05
# 2021-01-06
# 2021-01-06
# 2021-01-06
# 2021-01-06
# 2021-01-06
# 2021-01-06
# 2021-01-06
# 2021-01-06
# 2021-01-06
# 2021-01-06
# 2021-01-06
# 2021-01-06
# 2021-01-07
# 2021-01-07
# 2021-01-07
# 2021-01-07
# 2021-01-07
# 2021-01-07
# 2021-01-07
# 2021-01-07
# 2021-01-07
# 2021-01-07
# 2021-01-08
# 2021-01-08
# 2021-01-08
# 2021-01-08
# 2021-01-08
# 2021-01-08
# 2021-01-08
# 2021-01-08
# 2021-01-08
# 2021-01-09
# 2021-01-09
# 2021-01-09
# 2021-01-09
# 2021-01-09
# 2021-01-09
# 2021-01-09
# 2021-01-09
# 2021-01-09
# 2021-01-10
# 2021-01-10
# 2021-01-10
# 2021-01-10
# 2021-01-10
# 2021-01-11
# 2021-01-11
# 2021-01-11
# 2021-01-11
# 2021-01-11
# 2021-01-11
# 2021-01-11
# 2021-01-12
# 2021-01-12
# 2021-01-12
# 2021-01-12
# 2021-01-12
# 2021-01-12
# 2021-01-12
# 2021-01-12
# 2021-01-13
# 2021-01-13
# 2021-01-13
# 2021-01-13
# 2021-01-14
# 2021-01-14
# 2021-01-14
# 2021-01-14
# 2021-01-14
# 2021-01-14
# 2021-01-14
# 2021-01-14
# 2021-01-14
# 2021-01-14
# 2021-01-15
# 2021-01-15
# 2021-01-15
# 2021-01-15
# 2021-01-15
# 2021-01-15
# 2021-01-15
# 2021-01-15
# 2021-01-15
# 2021-01-16
# 2021-01-16
# 2021-01-16
# 2021-01-16
# 2021-01-16
# 2021-01-16
# 2021-01-16
# 2021-01-16
# 2021-01-17
# 2021-01-17
# 2021-01-17
# 2021-01-17
# 2021-01-17
# 2021-01-17
# 2021-01-17
# 2021-01-17
# 2021-01-17
# 2021-01-17
# 2021-01-17
# 2021-01-17
# 2021-01-18
# 2021-01-18
# 2021-01-18
# 2021-01-18
# 2021-01-18
# 2021-01-18
# 2021-01-18
# 2021-01-18
# 2021-01-18
# 2021-01-19
# 2021-01-19
# 2021-01-19
# 2021-01-19
# 2021-01-19
# 2021-01-19
# 2021-01-19
# 2021-01-19
# 2021-01-19
# 2021-01-19
# 2021-01-19
# 2021-01-19
# 2021-01-20
# 2021-01-20
# 2021-01-20
# 2021-01-20
# 2021-01-20
# 2021-01-20
# 2021-01-20
# 2021-01-20
# 2021-01-20
# 2021-01-20
# 2021-01-20
# 2021-01-20
# 2021-01-20
# 2021-01-20
# 2021-01-20
# 2021-01-20
# 2021-01-20
# 2021-01-21
# 2021-01-21
# 2021-01-21
# 2021-01-21
# 2021-01-21
# 2021-01-21
# 2021-01-21
# 2021-01-21
# 2021-01-21
# 2021-01-21
# 2021-01-22
# 2021-01-22
# 2021-01-22
# 2021-01-22
# 2021-01-22
# 2021-01-22
# 2021-01-22
# 2021-01-22
# 2021-01-22
# 2021-01-22
# 2021-01-22
# 2021-01-22
# 2021-01-23
# 2021-01-23
# 2021-01-23
# 2021-01-23
# 2021-01-23
# 2021-01-23
# 2021-01-23
# 2021-01-23
# 2021-01-23
# 2021-01-23
# 2021-01-24
# 2021-01-24
# 2021-01-24
# 2021-01-24
# 2021-01-24
# 2021-01-24
# 2021-01-24
# 2021-01-25
# 2021-01-25
# 2021-01-25
# 2021-01-25
# 2021-01-25
# 2021-01-25
# 2021-01-25
# 2021-01-25
# 2021-01-25
# 2021-01-25
# 2021-01-26
# 2021-01-26
# 2021-01-26
# 2021-01-26
# 2021-01-26
# 2021-01-26
# 2021-01-26
# 2021-01-26
# 2021-01-27
# 2021-01-27
# 2021-01-27
# 2021-01-27
# 2021-01-27
# 2021-01-27
# 2021-01-27
# 2021-01-27
# 2021-01-27
# 2021-01-27
# 2021-01-27
# 2021-01-28
# 2021-01-28
# 2021-01-28
# 2021-01-28
# 2021-01-28
# 2021-01-28
# 2021-01-28
# 2021-01-28
# 2021-01-28
# 2021-01-28
# 2021-01-28
# 2021-01-28
# 2021-01-28
# 2021-01-28
# 2021-01-29
# 2021-01-29
# 2021-01-29
# 2021-01-29
# 2021-01-29
# 2021-01-29
# 2021-01-29
# 2021-01-29
# 2021-01-29
# 2021-01-29
# 2021-01-29
# 2021-01-29
# 2021-01-29
# 2021-01-29
# 2021-01-29
# 2021-01-30
# 2021-01-30
# 2021-01-30
# 2021-01-30
# 2021-01-30
# 2021-01-30
# 2021-01-30
# 2021-01-30
# 2021-01-30
# 2021-01-30
# 2021-01-30
# 2021-01-30
# 2021-01-31
# 2021-01-31
# 2021-01-31
# 2021-01-31
# 2021-01-31
# 2021-01-31
# 2021-01-31
# 2021-01-31
# 2021-01-31
# 2021-01-31
# 2021-02-01
# 2021-02-01
# 2021-02-01
# 2021-02-01
# 2021-02-01
# 2021-02-01
# 2021-02-01
# 2021-02-01
# 2021-02-01
# 2021-02-01
# 2021-02-01
# 2021-02-02
# 2021-02-02
# 2021-02-02
# 2021-02-02
# 2021-02-02
# 2021-02-02
# 2021-02-02
# 2021-02-02
# 2021-02-03
# 2021-02-03
# 2021-02-03
# 2021-02-03
# 2021-02-03
# 2021-02-03
# 2021-02-03
# 2021-02-04
# 2021-02-04
# 2021-02-04
# 2021-02-04
# 2021-02-04
# 2021-02-04
# 2021-02-05
# 2021-02-05
# 2021-02-05
# 2021-02-05
# 2021-02-05
# 2021-02-05
# 2021-02-05
# 2021-02-05
# 2021-02-05
# 2021-02-06
# 2021-02-06
# 2021-02-06
# 2021-02-06
# 2021-02-06
# 2021-02-06
# 2021-02-06
# 2021-02-06
# 2021-02-07
# 2021-02-07
# 2021-02-07
# 2021-02-07
# 2021-02-07
# 2021-02-07
# 2021-02-07
# 2021-02-07
# 2021-02-07
# 2021-02-07
# 2021-02-07
# 2021-02-07
# 2021-02-07
# 2021-02-08
# 2021-02-08
# 2021-02-08
# 2021-02-08
# 2021-02-08
# 2021-02-08
# 2021-02-08
# 2021-02-08
# 2021-02-08
# 2021-02-08
# 2021-02-08
# 2021-02-08
# 2021-02-10
# 2021-02-10
# 2021-02-10
# 2021-02-10
# 2021-02-10
# 2021-02-11
# 2021-02-11
# 2021-02-11
# 2021-02-11
# 2021-02-11
# 2021-02-11
# 2021-02-11
# 2021-02-11
# 2021-02-11
# 2021-02-11
# 2021-02-12
# 2021-02-12
# 2021-02-12
# 2021-02-12
# 2021-02-12
# 2021-02-12
# 2021-02-12
# 2021-02-12
# 2021-02-12
# 2021-02-12
# 2021-02-13
# 2021-02-13
# 2021-02-13
# 2021-02-13
# 2021-02-13
# 2021-02-13
# 2021-02-13
# 2021-02-13
# 2021-02-14
# 2021-02-14
# 2021-02-14
# 2021-02-14
# 2021-02-15
# 2021-02-15
# 2021-02-15
# 2021-02-15
# 2021-02-16
# 2021-02-16
# 2021-02-16
# 2021-02-16
# 2021-02-16
# 2021-02-16
# 2021-02-16
# 2021-02-16
# 2021-02-17
# 2021-02-17
# 2021-02-17
# 2021-02-17
# 2021-02-17
# 2021-02-17
# 2021-02-17
# 2021-02-18
# 2021-02-18
# 2021-02-18
# 2021-02-18
# 2021-02-19
# 2021-02-19
# 2021-02-19
# 2021-02-19
# 2021-02-19
# 2021-02-19
# 2021-02-19
# 2021-02-19
# 2021-02-19
# 2021-02-19
# 2021-02-19
# 2021-02-19
# 2021-02-20
# 2021-02-20
# 2021-02-20
# 2021-02-20
# 2021-02-20
# 2021-02-20
# 2021-02-20
# 2021-02-20
# 2021-02-20
# 2021-02-20
# 2021-02-21
# 2021-02-21
# 2021-02-21
# 2021-02-21
# 2021-02-21
# 2021-02-21
# 2021-02-22
# 2021-02-22
# 2021-02-22
# 2021-02-22
# 2021-02-22
# 2021-02-22
# 2021-02-22
# 2021-02-22
# 2021-02-22
# 2021-02-22
# 2021-02-22
# 2021-02-23
# 2021-02-23
# 2021-02-23
# 2021-02-23
# 2021-02-23
# 2021-02-23
# 2021-02-24
# 2021-02-24
# 2021-02-24
# 2021-02-24
# 2021-02-24
# 2021-02-24
# 2021-02-24
# 2021-02-24
# 2021-02-24
# 2021-02-24
# 2021-02-24
# 2021-02-25
# 2021-02-25
# 2021-02-25
# 2021-02-25
# 2021-02-25
# 2021-02-26
# 2021-02-26
# 2021-02-26
# 2021-02-26
# 2021-02-26
# 2021-02-26
# 2021-02-26
# 2021-02-26
# 2021-02-26
# 2021-02-26
# 2021-02-27
# 2021-02-27
# 2021-02-27
# 2021-02-27
# 2021-02-27
# 2021-02-27
# 2021-02-27
# 2021-02-27
# 2021-02-28
# 2021-02-28
# 2021-02-28
# 2021-03-01
# 2021-03-01
# 2021-03-01
# 2021-03-01
# 2021-03-01
# 2021-03-01
# 2021-03-02
# 2021-03-02
# 2021-03-03
# 2021-03-03
# 2021-03-03
# 2021-03-03
# 2021-03-03
# 2021-03-03
# 2021-03-03
# 2021-03-03
# 2021-03-03
# 2021-03-03
# 2021-03-03
# 2021-03-03
# 2021-03-04
# 2021-03-04
# 2021-03-04
# 2021-03-04
# 2021-03-04
# 2021-03-04
# 2021-03-04
# 2021-03-04
# 2021-03-04
# 2021-03-04
# 2021-03-04
# 2021-03-05
# 2021-03-05
# 2021-03-05
# 2021-03-05
# 2021-03-05
# 2021-03-05
# 2021-03-05
# 2021-03-05
# 2021-03-05
# 2021-03-05
# 2021-03-05
# 2021-03-05
# 2021-03-05
# 2021-03-05
# 2021-03-06
# 2021-03-06
# 2021-03-06
# 2021-03-06
# 2021-03-06
# 2021-03-06
# 2021-03-06
# 2021-03-07
# 2021-03-07
# 2021-03-07
# 2021-03-07
# 2021-03-07
# 2021-03-07
# 2021-03-07
# 2021-03-07
# 2021-03-07
# 2021-03-07
# 2021-03-07
# 2021-03-08
# 2021-03-08
# 2021-03-08
# 2021-03-08
# 2021-03-08
# 2021-03-08
# 2021-03-08
# 2021-03-09
# 2021-03-09
# 2021-03-09
# 2021-03-09
# 2021-03-09
# 2021-03-09
# 2021-03-09
# 2021-03-09
# 2021-03-10
# 2021-03-10
# 2021-03-10
# 2021-03-10
# 2021-03-10
# 2021-03-10
# 2021-03-10
# 2021-03-10
# 2021-03-10
# 2021-03-10
# 2021-03-10
# 2021-03-11
# 2021-03-11
# 2021-03-11
# 2021-03-11
# 2021-03-11
# 2021-03-11
# 2021-03-11
# 2021-03-11
# 2021-03-11
# 2021-03-11
# 2021-03-11
# 2021-03-11
# 2021-03-11
# 2021-03-11
# 2021-03-11
# 2021-03-11
# 2021-03-11
# 2021-03-12
# 2021-03-12
# 2021-03-12
# 2021-03-12
# 2021-03-12
# 2021-03-12
# 2021-03-12
# 2021-03-12
# 2021-03-12
# 2021-03-12
# 2021-03-13
# 2021-03-13
# 2021-03-13
# 2021-03-13
# 2021-03-13
# 2021-03-13
# 2021-03-13
# 2021-03-13
# 2021-03-13
# 2021-03-13
# 2021-03-13
# 2021-03-13
# 2021-03-13
# 2021-03-13
# 2021-03-13
# 2021-03-14
# 2021-03-14
# 2021-03-14
# 2021-03-14
# 2021-03-14
# 2021-03-15
# 2021-03-15
# 2021-03-15
# 2021-03-15
# 2021-03-15
# 2021-03-15
# 2021-03-16
# 2021-03-16
# 2021-03-16
# 2021-03-16
# 2021-03-16
# 2021-03-16
# 2021-03-16
# 2021-03-16
# 2021-03-16
# 2021-03-16
# 2021-04-02
# 2021-04-02
# 2021-04-02
# 2021-04-02
# 2021-04-02
# 2021-04-02
# 2021-04-02
# 2021-04-03
# 2021-04-03
# 2021-04-03
# 2021-04-03
# 2021-04-03
# 2021-04-03
# 2021-04-03
# 2021-04-03
# 2021-04-03
# 2021-04-03
# 2021-04-04
# 2021-04-04
# 2021-04-04
# 2021-04-04
# 2021-04-04
# 2021-04-05
# 2021-04-05
# 2021-04-05
# 2021-04-05
# 2021-04-05
# 2021-04-05
# 2021-04-05
# 2021-04-05
# 2021-04-05
# 2021-04-06
# 2021-04-06
# 2021-04-06
# 2021-04-06
# 2021-04-06
# 2021-04-06
# 2021-04-07
# 2021-04-07
# 2021-04-07
# 2021-04-07
# 2021-04-07
# 2021-04-07
# 2021-04-07
# 2021-04-07
# 2021-04-07
# 2021-04-07
# 2021-04-07
# 2021-04-08
# 2021-04-08
# 2021-04-08
# 2021-04-08
# 2021-04-08
# 2021-04-08
# 2021-04-08
# 2021-04-09
# 2021-04-09
# 2021-04-09
# 2021-04-09
# 2021-04-09
# 2021-04-10
# 2021-04-10
# 2021-04-10
# 2021-04-11
# 2021-04-11
# 2021-04-11
# 2021-04-11
# 2021-04-11
# 2021-04-11
# 2021-04-11
# 2021-04-12
# 2021-04-12
# 2021-04-12
# 2021-04-12
# 2021-04-12
# 2021-04-12
# 2021-04-12
# 2021-04-12
# 2021-04-12
# 2021-04-12
# 2021-04-12
# 2021-04-12
# 2021-04-12
# 2021-04-12
# 2021-04-12
# 2021-04-12
# 2021-04-12
# 2021-04-12
# 2021-04-13
# 2021-04-13
# 2021-04-13
# 2021-04-13
# 2021-04-13
# 2021-04-13
# 2021-04-13
# 2021-04-13
# 2021-04-13
# 2021-04-13
# 2021-04-13
# 2021-04-13
# 2021-04-13
# 2021-04-13
# 2021-04-13
# 2021-04-13
# 2021-04-14
# 2021-04-14
# 2021-04-14
# 2021-04-14
# 2021-04-14
# 2021-04-14
# 2021-04-14
# 2021-04-14
# 2021-04-14
# 2021-04-15
# 2021-04-15
# 2021-04-15
# 2021-04-15
# 2021-04-15
# 2021-04-15
# 2021-04-16
# 2021-04-16
# 2021-04-16
# 2021-04-16
# 2021-04-16
# 2021-04-16
# 2021-04-16
# 2021-04-17
# 2021-04-17
# 2021-04-17
# 2021-04-17
# 2021-04-17
# 2021-04-18
# 2021-04-18
# 2021-04-18
# 2021-04-18
# 2021-04-18
# 2021-04-18
# 2021-04-18
# 2021-04-19
# 2021-04-19
# 2021-04-19
# 2021-04-19
# 2021-04-19
# 2021-04-19
# 2021-04-19
# 2021-04-19
# 2021-04-19
# 2021-04-19
# 2021-04-19
# 2021-04-19
# 2021-04-19
# 2021-04-19
# 2021-04-19
# 2021-04-19
# 2021-04-19
# 2021-04-19
# 2021-04-20
# 2021-04-20
# 2021-04-20
# 2021-04-20
# 2021-04-20
# 2021-04-20
# 2021-04-20
# 2021-04-20
# 2021-04-20
# 2021-04-20
# 2021-04-20
# 2021-04-21
# 2021-04-21
# 2021-04-21
# 2021-04-21
# 2021-04-21
# 2021-04-21
# 2021-04-21
# 2021-04-21
# 2021-04-21
# 2021-04-21
# 2021-04-21
# 2021-04-22
# 2021-04-22
# 2021-04-22
# 2021-04-22
# 2021-04-22
# 2021-04-22
# 2021-04-23
# 2021-04-23
# 2021-04-23
# 2021-04-23
# 2021-04-23
# 2021-04-24
# 2021-04-24
# 2021-04-24
# 2021-04-24
# 2021-04-24
# 2021-04-25
# 2021-04-25
# 2021-04-25
# 2021-04-25
# 2021-04-25
# 2021-04-25
# 2021-04-25
# 2021-04-25
# 2021-04-25
# 2021-04-26
# 2021-04-26
# 2021-04-26
# 2021-04-26
# 2021-04-26
# 2021-04-26
# 2021-04-26
# 2021-04-26
# 2021-04-26
# 2021-04-26
# 2021-04-27
# 2021-04-27
# 2021-04-27
# 2021-04-27
# 2021-04-27
# 2021-04-27
# 2021-04-27
# 2021-04-27
# 2021-04-27
# 2021-04-28
# 2021-04-28
# 2021-04-28
# 2021-04-28
# 2021-04-28
# 2021-04-28
# 2021-04-28
# 2021-04-29
# 2021-04-29
# 2021-04-29
# 2021-04-29
# 2021-04-29
# 2021-04-29
# 2021-04-29
# 2021-04-30
# 2021-04-30
# 2021-04-30
# 2021-04-30
# 2021-04-30
# 2021-04-30
# 2021-04-30
# 2021-04-30
# 2021-04-30
# 2021-04-30
# 2021-05-01
# 2021-05-01
# 2021-05-01
# 2021-05-01
# 2021-05-01
# 2021-05-01
# 2021-05-01
# 2021-05-01
# 2021-05-02
# 2021-05-02
# 2021-05-02
# 2021-05-02
# 2021-05-02
# 2021-05-02
# 2021-05-02
# 2021-05-02
# 2021-05-03
# 2021-05-03
# 2021-05-03
# 2021-05-03
# 2021-05-03
# 2021-05-03
# 2021-05-03
# 2021-05-03
# 2021-05-03
# 2021-05-03
# 2021-05-03
# 2021-05-04
# 2021-05-04
# 2021-05-04
# 2021-05-04
# 2021-05-04
# 2021-05-04
# 2021-05-04
# 2021-05-04
# 2021-05-04
# 2021-05-04
# 2021-05-04
# 2021-05-04
# 2021-05-04
# 2021-05-04
# 2021-05-05
# 2021-05-05
# 2021-05-05
# 2021-05-05
# 2021-05-05
# 2021-05-05
# 2021-05-05
# 2021-05-05
# 2021-05-05
# 2021-05-05
# 2021-05-05
# 2021-05-05
# 2021-05-06
# 2021-05-06
# 2021-05-06
# 2021-05-06
# 2021-05-06
# 2021-05-06
# 2021-05-07
# 2021-05-07
# 2021-05-07
# 2021-05-07
# 2021-05-07
# 2021-05-07
# 2021-05-07
# 2021-05-07
# 2021-05-07
# 2021-05-08
# 2021-05-08
# 2021-05-08
# 2021-05-08
# 2021-05-08
# 2021-05-08
# 2021-05-08
# 2021-05-08
# 2021-05-08
# 2021-05-08
# 2021-05-08
# 2021-05-08
# 2021-05-09
# 2021-05-09
# 2021-05-09
# 2021-05-09
# 2021-05-09
# 2021-05-09
# 2021-05-09
# 2021-05-09
# 2021-05-10
# 2021-05-10
# 2021-05-10
# 2021-05-10
# 2021-05-10
# 2021-05-10
# 2021-05-10
# 2021-05-11
# 2021-05-11
# 2021-05-11
# 2021-05-11
# 2021-05-11
# 2021-05-11
# 2021-05-11
# 2021-05-11
# 2021-05-11
# 2021-05-11
# 2021-05-11
# 2021-05-12
# 2021-05-12
# 2021-05-12
# 2021-05-12
# 2021-05-12
# 2021-05-12
# 2021-05-13
# 2021-05-13
# 2021-05-13
# 2021-05-13
# 2021-05-13
# 2021-05-13
# 2021-05-13
# 2021-05-13
# 2021-05-14
# 2021-05-14
# 2021-05-14
# 2021-05-14
# 2021-05-14
# 2021-05-14
# 2021-05-14
# 2021-05-14
# 2021-05-14
# 2021-05-15
# 2021-05-15
# 2021-05-15
# 2021-05-15
# 2021-05-15
# 2021-05-15
# 2021-05-15
# 2021-05-15
# 2021-05-15
# 2021-05-15
# 2021-05-15
# 2021-05-15
# 2021-05-16
# 2021-05-16
# 2021-05-16
# 2021-05-16
# 2021-05-16
# 2021-05-16
# 2021-05-16
# 2021-05-16
# 2021-05-16
# 2021-05-16
# 2021-05-16
# 2021-05-17
# 2021-05-17
# 2021-05-17
# 2021-05-17
# 2021-05-17
# 2021-05-17
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-18
# 2021-05-19
# 2021-05-19
# 2021-05-19
# 2021-05-19
# 2021-05-19
# 2021-05-19
# 2021-05-19
# 2021-05-19
# 2021-05-19
# 2021-05-19
# 2021-05-19
# 2021-05-19
# 2021-05-20
# 2021-05-20
# 2021-05-20
# 2021-05-20
# 2021-05-20
# 2021-05-20
# 2021-05-21
# 2021-05-21
# 2021-05-21
# 2021-05-21
# 2021-05-21
# 2021-05-22
# 2021-05-22
# 2021-05-22
# 2021-05-22
# 2021-05-22
# 2021-05-22
# 2021-05-22
# 2021-05-23
# 2021-05-23
# 2021-05-23
# 2021-05-23
# 2021-05-23
# 2021-05-23
# 2021-05-23
# 2021-05-23
# 2021-05-23
# 2021-05-23
# 2021-05-24
# 2021-05-24
# 2021-05-24
# 2021-05-24
# 2021-05-24
# 2021-05-24
# 2021-05-24
# 2021-05-24
# 2021-05-24
# 2021-05-24
# 2021-05-24
# 2021-05-25
# 2021-05-25
# 2021-05-25
# 2021-05-25
# 2021-05-25
# 2021-05-25
# 2021-05-25
# 2021-05-25
# 2021-05-25
# 2021-05-25
# 2021-05-26
# 2021-05-26
# 2021-05-26
# 2021-05-26
# 2021-05-26
# 2021-05-26
# 2021-05-26
# 2021-05-27
# 2021-05-27
# 2021-05-27
# 2021-05-27
# 2021-05-27
# 2021-05-27
# 2021-05-27
# 2021-05-27
# 2021-05-27
# 2021-05-27
# 2021-05-27
# 2021-05-28
# 2021-05-28
# 2021-05-28
# 2021-05-28
# 2021-05-28
# 2021-05-28
# 2021-05-28
# 2021-05-28
# 2021-05-28
# 2021-05-29
# 2021-05-29
# 2021-05-29
# 2021-05-29
# 2021-05-29
# 2021-05-29
# 2021-05-29
# 2021-05-29
# 2021-05-30
# 2021-05-30
# 2021-05-30
# 2021-05-30
# 2021-05-30
# 2021-05-31
# 2021-05-31
# 2021-05-31
# 2021-05-31
# 2021-05-31
# 2021-05-31

# %%
len(df_date)
# Out:
# 1215

# %% [markdown]
# ### Sentiment Analysis on the text

# %%
authenticator = IAMAuthenticator('jRPjC58jsnApfEa4CX0UbnHT18FoL7PfWjKdYemPSw8c')
tone_analyzer = ToneAnalyzerV3(
    version="2017-09-21",
    authenticator=authenticator
)

tone_analyzer.set_service_url('https://api.eu-gb.tone-analyzer.watson.cloud.ibm.com/instances/7373c8d2-41fc-41ae-89a0-7c9531df0666')
tone_analyzer.set_disable_ssl_verification(True)

# %%
# to avoid warning message in the next shell
import urllib3
urllib3.disable_warnings()

# %%
list_Emotion=[]
for text in df_text:
  tone_analysis = tone_analyzer.tone(
      {'text': text},
      content_type='application/json'
  ).get_result()
  test=json.dumps(tone_analysis, indent=2)

  dic=json.loads(test) 
  # print(dic)
  tones=[]
  if ('sentences_tone' in dic.keys()):
    for sid in dic['sentences_tone']:
      #print(sid)
      for tones in sid['tones']:
        # print(tones['tone_name'])
        list_Emotion.append(tones['tone_name'])
# Out:
# {'sentence_id': 0, 'text': 'Upped my steps today with a lovely walk by the coast then a slippy dog walk just now.', 'tones': [{'score': 0.764255, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.5538, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 1, 'text': 'Feeling positive until I let the little voice remind me it’s back to work in 2 days.', 'tones': [{'score': 0.518438, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.6821, 'tone_id': 'confident', 'tone_name': 'Confident'}]}
# {'sentence_id': 2, 'text': '#FitbitSENSE #WalkEveryDay2021', 'tones': []}
# {'sentence_id': 0, 'text': 'やっぱりfitbit senseが無難かなー。夫が隣でもうオーダーしようとしてるから慌てて止めたけど', 'tones': []}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': 'surface  proもオーダーしたばっかだけど普段ケチケチしてるくせに1度使い出すと止まらなくなるやっかいな性格', 'tones': [{'score': 0.702, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 0, 'text': 'لمحبي الساعات الذكية', 'tones': []}
# {'sentence_id': 1, 'text': 'عرضعلى ساعات Fitbit Sense and Versa 3', 'tones': []}
# {'sentence_id': 2, 'text': 'شحن مباشر من #امازون بريطانيا', 'tones': []}
# {'sentence_id': 3, 'text': '', 'tones': []}
# {'sentence_id': 4, 'text': 'https://amzn.to/2JGmxTy', 'tones': []}
# {'sentence_id': 0, 'text': 'Awesome “Sector” #watchface #clockface with stunning AOD mode by ', 'tones': [{'score': 0.705484, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '@supeerbcom', 'tones': []}
# {'sentence_id': 2, 'text': ' for #Fitbit #fitbitversa3 #fitbitsense #made4fitbit', 'tones': []}
# {'sentence_id': 0, 'text': 'Anyone out there have the Fitbit Sense?', 'tones': [{'score': 0.91961, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 1, 'text': 'I received it as a gift for Christmas and I’m struggling with all of the set up.', 'tones': [{'score': 0.502369, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.704642, 'tone_id': 'confident', 'tone_name': 'Confident'}, {'score': 0.664451, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 2, 'text': 'The instructions that came with it are crap, so I was wondering if there are some specific YouTube videos or websites that you have used to help you.￼', 'tones': [{'score': 0.831313, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 0, 'text': 'FITBIT SENSE Fitness Smartwatch Detailed Overview and Close Look at Inst... https://youtu.be/NPHnamIudRk via ', 'tones': [{'score': 0.932977, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 1, 'text': '@YouTube', 'tones': []}
# {'sentence_id': 0, 'text': 'If ', 'tones': [{'score': 0.997482, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 1, 'text': '@fitbit', 'tones': []}
# {'sentence_id': 2, 'text': ' would enable audible alerts on their new sense and versa lines for apps, maybe allowed on or off for specific apps and utilized the speaker for alarms as well, pumped up the volume, it’d be a real contender in the smart watch market.', 'tones': []}
# {'sentence_id': 3, 'text': 'Make the battery bigger and it’s #1', 'tones': []}
# {'sentence_id': 0, 'text': 'Heute kam mein Weihnachtsgeschenk von ', 'tones': []}
# {'sentence_id': 1, 'text': '@inovexgmbh', 'tones': []}
# {'sentence_id': 2, 'text': ' an ', 'tones': []}
# {'sentence_id': 3, 'text': '', 'tones': []}
# {'sentence_id': 4, 'text': 'Beste Firma ever, auch in 2021!', 'tones': [{'score': 0.97759, 'tone_id': 'confident', 'tone_name': 'Confident'}]}
# {'sentence_id': 5, 'text': "Und, ich fühl' mich gleich viel sportlicher ", 'tones': []}
# {'sentence_id': 6, 'text': '', 'tones': []}
# {'sentence_id': 7, 'text': '#Fitbit #Sense #fitness', 'tones': [{'score': 0.500524, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 0, 'text': '2021 Sin excusas#FitbitSENSE ', 'tones': []}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': 'Como bien saben mis canarios: Todo lo que esté por debajo de los 20°C es #frío \u200d', 'tones': []}
# {'sentence_id': 3, 'text': '', 'tones': []}
# {'sentence_id': 4, 'text': 'Hoy Luna lo ha puesto de excusa', 'tones': [{'score': 0.523192, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 0, 'text': 'これ、なにげにいいッスよ！', 'tones': []}
# {'sentence_id': 1, 'text': '#Fitbit ', 'tones': []}
# {'sentence_id': 2, 'text': '', 'tones': []}
# {'sentence_id': 3, 'text': 'スマートウォッチ(Gray/Silver Aluminium）S・Lサイズ兼用 | Joshin webショップ 通販| フィットビット | FB505SRGY-CJK', 'tones': []}
# {'sentence_id': 0, 'text': 'Todos con sus apple watch, pero yo prefiero mil veces fitbit!.', 'tones': []}
# {'sentence_id': 1, 'text': 'Quiero un fitbit  sense', 'tones': []}
# {'sentence_id': 0, 'text': 'chromebookが2万弱で売っていたので買ってしまった。', 'tones': []}
# {'sentence_id': 1, 'text': '加えて、fitbit senseも買ってしまった。', 'tones': []}
# {'sentence_id': 2, 'text': '', 'tones': []}
# {'sentence_id': 3, 'text': '頑張って仕事しよう。', 'tones': []}
# {'sentence_id': 0, 'text': 'fitbit senseにするか…', 'tones': []}
# {'sentence_id': 1, 'text': '本体は日曜日にYahooで買って…', 'tones': []}
# {'sentence_id': 2, 'text': 'アクセサリセール中のはAmazonで買って1万プラスくらいか？', 'tones': []}
# {'sentence_id': 0, 'text': 'Fitbit SenseとVersa3とCharge4とInspire2の違いを33の観点で徹底比較！ https://arare-blog.com/fitbitsenseversa3charge4inspire2…', 'tones': [{'score': 0.755679, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': 'これ見るとSenseほしいなと思ってしまうけど、たぶんこの次に出る新作がすげえ重要な気がするよな...。今はInspire2あたりで使用感見ていくのが良いのかなあ～～', 'tones': [{'score': 0.915494, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 0, 'text': 'Fitbit Sense, smartwatch para quienes buscan remedio para el estrés', 'tones': []}
# {'sentence_id': 1, 'text': 'Fitbit Sense, el más reciente gadget de la marca que Google adquirió a finales de 2019.', 'tones': []}
# {'sentence_id': 0, 'text': 'Very sweet “Corgi” #watchface #clockface by ', 'tones': [{'score': 0.948578, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.942582, 'tone_id': 'confident', 'tone_name': 'Confident'}]}
# {'sentence_id': 1, 'text': '@DianasAnimals', 'tones': []}
# {'sentence_id': 2, 'text': ' for #Fitbit #fitbitversa2 #fitbitversa3 #fitbitsense #made4fitbit', 'tones': []}
# {'sentence_id': 0, 'text': 'Looks great on the new hardware!', 'tones': [{'score': 0.828817, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': 'Colourful “PaintSplash” #watchface #clockface with great AOD mode by Rhonda Hill ', 'tones': []}
# {'sentence_id': 2, 'text': '@RhondaCodes', 'tones': []}
# {'sentence_id': 3, 'text': ' for #Fitbit #fitbitversa2 #fitbitversa3 #fitbitsense #made4fitbit', 'tones': []}
# {'sentence_id': 0, 'text': '今日からFitbit Senseが私のパーソナルトレーナーに就任しました！', 'tones': []}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': '#Fitbit #スマートウォッチ', 'tones': []}
# {'sentence_id': 0, 'text': 'Apple Watchにsenseのバッテリー足りないって教えられてた。', 'tones': []}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': 'AppleWatch6とsenseを両方つけてる人に、あるある？な現象。', 'tones': []}
# {'sentence_id': 3, 'text': '', 'tones': []}
# {'sentence_id': 4, 'text': '#AppleWatch #fitbit', 'tones': []}
# {'sentence_id': 0, 'text': 'Why is my Sense or other Fitbit not connecting to Bluetooth?', 'tones': [{'score': 0.786991, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 1, 'text': '#wearables #wearabletech #smartwatch https://gadgetsandwearables.com/2021/01/04/why-is-my-fitbit-sense-not-connecting-to-bluetooth/…', 'tones': []}
# {'sentence_id': 0, 'text': 'Updated my Glitter watch face so it supports the new #fitbit watchfaces now.', 'tones': []}
# {'sentence_id': 1, 'text': 'Avaliable for #fitbitversa3 #fitbitsense #fitbitversa #fitbitionic #fitbitversalite #fitbitversa2 #made4fitbit', 'tones': []}
# {'sentence_id': 0, 'text': 'Fantastic new “SpO2” #watchface #clockface with beautiful AOD mode by ', 'tones': [{'score': 0.965834, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '@fitbitdev', 'tones': []}
# {'sentence_id': 2, 'text': ' for #fitbit #fitbitsense #fitbitversa3 #made4fitbit', 'tones': []}
# {'sentence_id': 0, 'text': 'Augmented- simple, clean look  with #NextGen #Animation exclusively on #FitbitVersa3 #FitbitSense- #made4fitbit #fitbitDev #fitbitSense #developer ', 'tones': [{'score': 0.765657, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '@NiVZ', 'tones': []}
# {'sentence_id': 0, 'text': 'One Day ', 'tones': []}
# {'sentence_id': 1, 'text': '@Fitbit', 'tones': []}
# {'sentence_id': 2, 'text': ' sale on ', 'tones': []}
# {'sentence_id': 3, 'text': '@amazon', 'tones': []}
# {'sentence_id': 4, 'text': ' (01/04/21) Fitbit Sense $278.95 (reg $329.95) https://amzn.to/358kUW6', 'tones': []}
# {'sentence_id': 5, 'text': 'and Fitbit Versa 2 $149.95', 'tones': []}
# {'sentence_id': 6, 'text': '(reg $179.95)', 'tones': []}
# {'sentence_id': 0, 'text': "It's here ", 'tones': []}
# {'sentence_id': 1, 'text': '#FitbitSENSE', 'tones': []}
# {'sentence_id': 0, 'text': 'Amazing NextGen animations with “Augmented” #watchface #clockface by \u2066', 'tones': [{'score': 0.946761, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '@GroenMarc', 'tones': []}
# {'sentence_id': 2, 'text': '\u2069 code magic by \u2066', 'tones': [{'score': 0.661534, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 3, 'text': '@NiVZ', 'tones': []}
# {'sentence_id': 4, 'text': '\u2069 for #fitbit #fitbitversa #fitbitsense #fitbitversa3 #made4fitbit Exclusive Preview - available soon!', 'tones': []}
# {'sentence_id': 0, 'text': 'Is my #clockface smiling at me?  Brand new “Cords” #watchface by Grégoire ', 'tones': [{'score': 0.811717, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '@GregoireSage', 'tones': []}
# {'sentence_id': 2, 'text': ' for #fitbit #fitbitversa #fitbitsense #fitbitversa3 #made4fitbit', 'tones': []}
# {'sentence_id': 0, 'text': "The Versa 3 is a cheaper alternative to the Fitbit Sense and it's a happy medium of health features and fitness tracking.", 'tones': [{'score': 0.637799, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '#health https://cnet.com/news/fitbit-versa-3-review-everything-you-need-in-a-smartwatch-plus-a-few-surprises/…', 'tones': [{'score': 0.880435, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 0, 'text': 'Fitbit、Senseが最新と思っていたら、Versa 3も出ているのですね。でもSenseの方が値段が高い。ということは、Senseの方が上位機種かな？', 'tones': []}
# {'sentence_id': 1, 'text': 'https://fitbit.com/jp/versa3', 'tones': []}
# {'sentence_id': 0, 'text': 'ほしいもの', 'tones': []}
# {'sentence_id': 1, 'text': 'Pixel4a', 'tones': []}
# {'sentence_id': 2, 'text': 'fitbit sense', 'tones': []}
# {'sentence_id': 0, 'text': 'http://Amazon.com: Fitbit Sense Advanced Smartwatch with Tools for Heart Health, Stress Management & Skin Temperature Trends, White/Gold, One Size (S & L Bands Included): Health & Personal Care https://amazon.com/Fitbit-Advanced-Smartwatch-Management-Temperature/dp/B08DFLG5SP…', 'tones': []}
# {'sentence_id': 1, 'text': '日本で買うよりやすい', 'tones': []}
# {'sentence_id': 0, 'text': 'Fitbit Sense vs Fitbit Versa 3 http://ow.ly/8COq30rrjvR', 'tones': []}
# {'sentence_id': 1, 'text': '[', 'tones': []}
# {'sentence_id': 2, 'text': '@TechRadar', 'tones': []}
# {'sentence_id': 3, 'text': ']', 'tones': []}
# {'sentence_id': 0, 'text': 'Das Armband von meiner Fitbit Versa Lite geht kaputt :( Idealer Zeitpunkt um die Sense zu kaufen :D Aber.. Ich wollte sparen... und die nächste große Anschaffung sollte eigentlich der ', 'tones': [{'score': 0.77543, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 1, 'text': '@trackle_de', 'tones': []}
# {'sentence_id': 2, 'text': ' sein', 'tones': []}
# {'sentence_id': 0, 'text': 'Great analog “ntprSvf” #watchface #clockface with beautiful AOD mode by ntpr ', 'tones': [{'score': 0.950392, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.653099, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 1, 'text': '@marcelsasik', 'tones': []}
# {'sentence_id': 2, 'text': ' for #fitbit #fitbitversa #fitbitsense #fitbitversa3 #made4fitbit', 'tones': []}
# {'sentence_id': 0, 'text': '10k today.', 'tones': []}
# {'sentence_id': 1, 'text': 'Well yesterday actually but that did not rhyme.', 'tones': [{'score': 0.661456, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.898327, 'tone_id': 'confident', 'tone_name': 'Confident'}, {'score': 0.506763, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 2, 'text': '#fitbit #fitbitcharge2 #charge2 #fitbitsense #walkrunjog #slowways #diabetesreversal #DiabetesUK #walkfordiabetes #runfordiabetes #walkforhealth #runforhealth #walkjogrun...', 'tones': []}
# {'sentence_id': 0, 'text': 'Anyone own a fitbit sense?', 'tones': [{'score': 0.968123, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 1, 'text': "It's a piece of junk, will not continuously sync! it needs to be returned!", 'tones': [{'score': 0.560098, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 0, 'text': "Hi all, I don't have real Versa 3 or Sense to test.", 'tones': []}
# {'sentence_id': 1, 'text': 'I am looking fort feedback about the accessibility of this clock : sizes, location of the heart rate when hands moved, visual reminder, and bugs #Fitbit #FitbitSENSE #made4fitbit', 'tones': []}
# {'sentence_id': 0, 'text': 'Fitbit Sense impressions: bought the smartwatch upon release and disappointed; returned.', 'tones': []}
# {'sentence_id': 1, 'text': 'Too much like my Ionic and promised new features were "coming soon".', 'tones': []}
# {'sentence_id': 2, 'text': 'Terrible way to launch a product.', 'tones': [{'score': 0.755807, 'tone_id': 'sadness', 'tone_name': 'Sadness'}, {'score': 0.961871, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 3, 'text': 'Fast forward to a couple days ago...', 'tones': []}
# {'sentence_id': 0, 'text': 'Siri has a sense of humor.', 'tones': []}
# {'sentence_id': 1, 'text': 'I was trying to type “forgot” and I so conveniently typed “Fitbit”.', 'tones': []}
# {'sentence_id': 2, 'text': 'I told Kyrie yesterday I would get him one.', 'tones': []}
# {'sentence_id': 0, 'text': 'いま、Fitbit senseをポチっちゃいそうな衝動を抑えきれず...', 'tones': []}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': '激しく格闘中！！', 'tones': []}
# {'sentence_id': 0, 'text': 'Avec la Sense, Fitbit étend son offre de santé connectée.', 'tones': []}
# {'sentence_id': 1, 'text': "Électrocardiogramme, scan de l'activité électrodermale, analyse de l'état de stress de l'utilisateur... cette montre connectée pousse l'exploration un peu plus loin que la concurrence.", 'tones': [{'score': 0.832004, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 0, 'text': 'I moved more yesterday than I have on any day in the past few years.', 'tones': [{'score': 0.514409, 'tone_id': 'sadness', 'tone_name': 'Sadness'}, {'score': 0.647986, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 1, 'text': "I didn't think I had it in me but I proved myself wrong and will continue to until I am where I wanna be.", 'tones': [{'score': 0.586648, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 2, 'text': '#StrongerThanIThought #GettingFit2021 #fitbitsense #Fitbit #LetsGooo #TheLoveSquad #TheLovespellPalace', 'tones': []}
# {'sentence_id': 0, 'text': 'Awesome analog “ntprFfs” #watchface #clockface with great AOD mode by ntpr ', 'tones': [{'score': 0.84413, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.653099, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 1, 'text': '@marcelsasik', 'tones': []}
# {'sentence_id': 2, 'text': ' for #fitbit #fitbitversa #fitbitsense #fitbitversa3 #made4fitbit', 'tones': []}
# {'sentence_id': 0, 'text': 'My 80 year old grandpa got a Fitbit for Christmas and he calls it his Tik Tok.', 'tones': [{'score': 0.585827, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 1, 'text': 'He is so pure.', 'tones': [{'score': 0.898327, 'tone_id': 'confident', 'tone_name': 'Confident'}]}
# {'sentence_id': 2, 'text': 'And it honestly makes sense.', 'tones': []}
# {'sentence_id': 0, 'text': 'うっしっしー', 'tones': []}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': 'AmazonでポチったFitbit Senseが届きましたよ', 'tones': []}
# {'sentence_id': 3, 'text': '', 'tones': []}
# {'sentence_id': 4, 'text': '早く散歩に行きたい！早く睡眠取りたい！緊張してストレスチェックしたい', 'tones': []}
# {'sentence_id': 0, 'text': '【Fitbit Versa 3】SenseやVersa2と比較多めのしっかりレビュー https://youtu.be/F6TRy9OTP-c', 'tones': []}
# {'sentence_id': 1, 'text': '@YouTube', 'tones': []}
# {'sentence_id': 2, 'text': 'より', 'tones': []}
# {'sentence_id': 0, 'text': 'This is the most I’ve made my plants grow since I got this awesome clock face for my Fitbit Sense!', 'tones': [{'score': 0.766903, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': 'I love it!', 'tones': [{'score': 0.880435, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 2, 'text': 'The more steps you take, the more the plants grow!', 'tones': []}
# {'sentence_id': 3, 'text': 'Awesome job, ', 'tones': [{'score': 0.899208, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 4, 'text': '@renowatch', 'tones': []}
# {'sentence_id': 0, 'text': 'Awesome new “wthr F” #watchface #clockface with great AOD mode by ', 'tones': [{'score': 0.934477, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '@dp_faces', 'tones': []}
# {'sentence_id': 2, 'text': ' for #Fitbit #fitbitversa3 #fitbitsense #made4fitbit', 'tones': []}
# {'sentence_id': 0, 'text': 'Fitness package from Fitbit just arrived - and I now have the Fitbit Sense!', 'tones': [{'score': 0.716301, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 1, 'text': 'Been wanting to try it out so excitedddd for this', 'tones': []}
# {'sentence_id': 0, 'text': 'What are your current top five #clockfaces ?', 'tones': []}
# {'sentence_id': 1, 'text': '#watchface #clockface for #fitbit #fitbitversa #fitbitversa2 #fitbitsense #fitbitversa3 #made4fitbit I’m looking forward to your comments!', 'tones': [{'score': 0.646679, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 0, 'text': 'No resulta tan difícil ¿verdad?', 'tones': [{'score': 0.882284, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 1, 'text': '(especialmente el paso 3).', 'tones': []}
# {'sentence_id': 2, 'text': 'Registra fácilmente tu estado de ánimo en #FitbitSense después de una sesión con el Escáner EDA, o en la aplicación de Fitbit, para ayudarte a reflexionar sobre lo que te hace sentir mejor', 'tones': []}
# {'sentence_id': 0, 'text': 'Very beautiful “ntprNtf” #watchface #clockface with great AOD mode by ntpr ', 'tones': [{'score': 0.950392, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.825035, 'tone_id': 'confident', 'tone_name': 'Confident'}]}
# {'sentence_id': 1, 'text': '@marcelsasik', 'tones': []}
# {'sentence_id': 2, 'text': ' for #fitbit #fitbitversa #fitbitsense #fitbitversa3 #made4fitbit', 'tones': []}
# {'sentence_id': 0, 'text': 'No resulta tan difícil ¿verdad?', 'tones': [{'score': 0.882284, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 1, 'text': '(especialmente el paso 3).', 'tones': []}
# {'sentence_id': 2, 'text': 'Registra fácilmente tu estado de ánimo en #FitbitSense después de una sesión con el Escáner EDA, o en la aplicación de Fitbit, para ayudarte a reflexionar sobre lo que te hace sentir mejor', 'tones': []}
# {'sentence_id': 0, 'text': 'Why Fitbit Sense ECG is your essential health tool for 2021 ', 'tones': [{'score': 0.649235, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.579436, 'tone_id': 'confident', 'tone_name': 'Confident'}]}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': 'https://wareable.com/fitbit/why-fitbit-ecg-is-your-essential-health-tool-for-2021-8246…', 'tones': []}
# {'sentence_id': 0, 'text': "By far one one of the best purchases that I've made in a very long time.", 'tones': [{'score': 0.780871, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.704642, 'tone_id': 'confident', 'tone_name': 'Confident'}]}
# {'sentence_id': 1, 'text': "I'm very late to owning a fitness/ smartwatch but I'm glad that I ended up getting a Fitbit Sense.", 'tones': [{'score': 0.667254, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.638987, 'tone_id': 'confident', 'tone_name': 'Confident'}]}
# {'sentence_id': 2, 'text': 'Will start to take better advantage of its features over time.', 'tones': []}
# {'sentence_id': 0, 'text': 'Hi ', 'tones': []}
# {'sentence_id': 1, 'text': '@FitbitSupport', 'tones': []}
# {'sentence_id': 2, 'text': ' @fitbit', 'tones': []}
# {'sentence_id': 3, 'text': ' @FitbitIN', 'tones': []}
# {'sentence_id': 4, 'text': ' pls let me know whether ecg will work with your Sense device in India', 'tones': []}
# {'sentence_id': 0, 'text': 'Fitbits are better than ever with the release of the Versa 3 and Sense.', 'tones': []}
# {'sentence_id': 1, 'text': 'If you have one, you need to know the tricks to make it even better.', 'tones': [{'score': 0.647986, 'tone_id': 'tentative', 'tone_name': 'Tentative'}, {'score': 0.781949, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 2, 'text': 'These watches do so much more than count your steps.', 'tones': []}
# {'sentence_id': 3, 'text': '#Fitbit ', 'tones': []}
# {'sentence_id': 4, 'text': '@Fitbitsupport', 'tones': []}
# {'sentence_id': 0, 'text': 'fitbit sense 使い始めて２週間。バッテリーに関してのメモ。SpO2（血中酸素ウェルネスTracker）アプリの有無で、減り具合が全然違う。アプリ有りの場合は１日で50%減少するが、無しの場合は30%。', 'tones': []}
# {'sentence_id': 1, 'text': 'SpO2 app drains battery.', 'tones': [{'score': 0.768712, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 2, 'text': '#fitbit #fitbitsense #battery #バッテリー\u3000 #電池 #SpO2  #血中酸素', 'tones': []}
# {'sentence_id': 0, 'text': 'New clock face wthr F!', 'tones': [{'score': 0.55985, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': 'Available for Fitbit Sense, Versa 3, Versa 2, Versa Lite, Versa, and Ionic.', 'tones': []}
# {'sentence_id': 3, 'text': 'https://gallery.fitbit.com/details/17e17b9b-1860-42e8-a122-4c7c577758c7…', 'tones': []}
# {'sentence_id': 4, 'text': '#made4fitbit #Fitbit #versa3 #Sense8', 'tones': []}
# {'sentence_id': 0, 'text': "The Versa 3 is a cheaper alternative to the Fitbit Sense and it's a happy medium of health features and fitness tracking.", 'tones': [{'score': 0.637799, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '#health https://cnet.com/news/fitbit-versa-3-review-everything-you-need-in-a-smartwatch-plus-a-few-surprises/…', 'tones': [{'score': 0.880435, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 0, 'text': 'that being said.', 'tones': []}
# {'sentence_id': 1, 'text': 'i’ve got like... a ton of cool shit.', 'tones': [{'score': 0.671794, 'tone_id': 'anger', 'tone_name': 'Anger'}, {'score': 0.615352, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 2, 'text': 'Galaxy Projector, Fitbit Sense, LED face mask.', 'tones': [{'score': 0.801827, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 3, 'text': 'i’m like temporarily not depressed about absolutely everything.', 'tones': [{'score': 0.55769, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.615352, 'tone_id': 'tentative', 'tone_name': 'Tentative'}, {'score': 0.506763, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 0, 'text': 'SwipeTime, a super simple timer for ', 'tones': [{'score': 0.846601, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.620279, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 1, 'text': '@Fitbit', 'tones': []}
# {'sentence_id': 2, 'text': ' smartwatches has been released for #Sense and #Versa3 as well—setting up a timer takes literally one swipe with it: http://bit.ly/2NM6Vvx', 'tones': [{'score': 0.705784, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 3, 'text': '#made4fitbit #fitbitversa2 #fitbitversa #fitbitversalite #fitbitionic', 'tones': []}
# {'sentence_id': 0, 'text': 'Hey ', 'tones': []}
# {'sentence_id': 1, 'text': '@FitbitIN', 'tones': []}
# {'sentence_id': 2, 'text': ' @fitbit', 'tones': []}
# {'sentence_id': 3, 'text': ' when you are launching Fitbit Sense officially in India ?', 'tones': [{'score': 0.724236, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 0, 'text': 'I’m updating BOLD for #FitbitVersa3 / #FitbitSENSE Pick one design  you don’t like!', 'tones': [{'score': 0.842108, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 1, 'text': 'It goes! #made4fitbit #free #clockface #onegoes #pickone #developer #steps #fitbit ', 'tones': []}
# {'sentence_id': 2, 'text': '@NiVZ', 'tones': []}
# {'sentence_id': 3, 'text': ' @FitbitDev', 'tones': []}
# {'sentence_id': 4, 'text': ' @fitbit', 'tones': []}
# {'sentence_id': 0, 'text': '#FitbitSENSE #Fitbit ', 'tones': []}
# {'sentence_id': 1, 'text': '@fitbit', 'tones': []}
# {'sentence_id': 2, 'text': ' looks like Fitbit dot com is down, absolutely zero response from here in the UK at 9 am GMT', 'tones': [{'score': 0.638987, 'tone_id': 'confident', 'tone_name': 'Confident'}, {'score': 0.599421, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 0, 'text': 'WTH is EDA Scan?', 'tones': []}
# {'sentence_id': 1, 'text': 'This innovative app on #FitbitSense measures your EDA responses to help you understand your body’s response to stressors, so you can learn to manage #stress better', 'tones': [{'score': 0.522862, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.73677, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 0, 'text': "Looking to upgrade my Fitbit Versa, I'm thinking about a straight upgrade to the Fitbit Sense but not sure if the Samsung watches are ready yet.", 'tones': [{'score': 0.589295, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 1, 'text': 'This is for a Samsung phone.', 'tones': []}
# {'sentence_id': 0, 'text': 'I just got a new ', 'tones': [{'score': 0.734944, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.968123, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 1, 'text': '@fitbit', 'tones': []}
# {'sentence_id': 2, 'text': ' sense and the box is a masterpiece by itself!! Props to whoever designed the package!!', 'tones': []}
# {'sentence_id': 0, 'text': '[#Review] Tras probarlo por un par de semanas, acá te contamos todo lo que debes saber sobre este nuevo reloj inteligente.', 'tones': []}
# {'sentence_id': 1, 'text': 'http://ow.ly/kDqB50D6AdW', 'tones': []}
# {'sentence_id': 2, 'text': '#Fitbit #FitbitSense #Tecnovitos', 'tones': []}
# {'sentence_id': 0, 'text': 'Apple Watch 6 vs Fitbit sense...', 'tones': []}
# {'sentence_id': 1, 'text': 'I think I’ma go with the sense', 'tones': [{'score': 0.801827, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 0, 'text': "I just discovered Fitbit Studio and it's AMAZING!", 'tones': [{'score': 0.893361, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.920855, 'tone_id': 'analytical', 'tone_name': 'Analytical'}, {'score': 0.88939, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 1, 'text': 'I went from signup to an app deployed and running on my sense in 5 minutes flat.', 'tones': []}
# {'sentence_id': 2, 'text': 'The code is concise and clear with easy to find docs for adding more.', 'tones': [{'score': 0.751512, 'tone_id': 'confident', 'tone_name': 'Confident'}, {'score': 0.711887, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 0, 'text': '昨晩Fitbit senseが届いたので付け替えてみる', 'tones': []}
# {'sentence_id': 1, 'text': '今まで使ってたFitbit versaはどうしようかねぇ', 'tones': []}
# {'sentence_id': 0, 'text': 'The new Fitbit Sense Advanced Smartwatch with Tools for Heart Health, Stress Management & Skin Temperature Trends is out ad >>>> https://amzn.to/38JLtTI', 'tones': []}
# {'sentence_id': 1, 'text': '#stayhome #workout', 'tones': [{'score': 0.791548, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 0, 'text': 'After the kind of year 2020 was, people hope that the new year brings better things.', 'tones': [{'score': 0.806158, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.88939, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 1, 'text': 'As people enter 2021 with a renewed sense of purpose, the wearable tracker and app Fitbit has come up with five ways they can stay inspired.', 'tones': [{'score': 0.798955, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.506763, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 2, 'text': 'READ: https://zcu.io/M2iA', 'tones': []}
# {'sentence_id': 0, 'text': 'Google completes Fitbit acquisition, says user privacy will be preserved and not used for targeted ads; it’s about “devices, not data”, which makes sense because Wear OS needs a leg-up and fitness is the way to do it.', 'tones': [{'score': 0.515972, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': 'But…', 'tones': []}
# {'sentence_id': 0, 'text': '【15日は全品5倍に+4倍でポイント最大32倍】 fitbit フィットビット Sense スマートウォッチ 消費カロリー 心拍数 メンズ レディース 腕時計 選べるモデル [楽天] https://a.r10.to/hDTGdk', 'tones': []}
# {'sentence_id': 1, 'text': '#rakuafl', 'tones': []}
# {'sentence_id': 0, 'text': 'After having 2 fitbit devices, the Sense is a step backwards.', 'tones': []}
# {'sentence_id': 1, 'text': 'How do I delete my "Sense" from the fitbit app?', 'tones': []}
# {'sentence_id': 2, 'text': 'It sucks', 'tones': []}
# {'sentence_id': 0, 'text': 'Finally, it’s official via email from #fitbit that FitBit joins #Google !', 'tones': [{'score': 0.773789, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': 'What will it bring to its existing users.', 'tones': []}
# {'sentence_id': 2, 'text': 'Already with Versa 3 and Sense, we see Fitbit entering the premium segment.', 'tones': []}
# {'sentence_id': 3, 'text': 'Would it even become pricier ?', 'tones': [{'score': 0.968123, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 0, 'text': 'Google has acquired Fitbit and I’m terrified about what they will do with user data going forward.', 'tones': [{'score': 0.74905, 'tone_id': 'fear', 'tone_name': 'Fear'}]}
# {'sentence_id': 1, 'text': 'This acquisition is driven by the potential to collect data from users.', 'tones': []}
# {'sentence_id': 2, 'text': 'Nothing else makes sense.', 'tones': [{'score': 0.762356, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 0, 'text': 'Hi ', 'tones': []}
# {'sentence_id': 1, 'text': '@fitbit', 'tones': []}
# {'sentence_id': 2, 'text': ' .', 'tones': []}
# {'sentence_id': 3, 'text': 'Just bought a #sense and watched ', 'tones': [{'score': 0.946222, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 4, 'text': '@dcrainmakerblog', 'tones': []}
# {'sentence_id': 5, 'text': ' review, which i thought fair.', 'tones': [{'score': 0.882284, 'tone_id': 'analytical', 'tone_name': 'Analytical'}, {'score': 0.822231, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 6, 'text': 'My summary', 'tones': [{'score': 0.997482, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 7, 'text': '1.', 'tones': []}
# {'sentence_id': 8, 'text': 'Its a beta++ product', 'tones': [{'score': 0.920855, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 9, 'text': '2. UX meta-navigation leaves you lost too often', 'tones': [{'score': 0.725358, 'tone_id': 'sadness', 'tone_name': 'Sadness'}, {'score': 0.615352, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 10, 'text': '3. data vs information balance is all wrong', 'tones': [{'score': 0.61247, 'tone_id': 'sadness', 'tone_name': 'Sadness'}, {'score': 0.91877, 'tone_id': 'confident', 'tone_name': 'Confident'}]}
# {'sentence_id': 11, 'text': 'Overall, I am disappointed with it right now.', 'tones': [{'score': 0.77933, 'tone_id': 'sadness', 'tone_name': 'Sadness'}, {'score': 0.615352, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 0, 'text': 'My sleep keeps getting worse.', 'tones': [{'score': 0.676526, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 1, 'text': 'Glad I have a Fitbit to track it.', 'tones': [{'score': 0.559807, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 2, 'text': 'Also glad they were bought by Google, so I can have better info integration.', 'tones': [{'score': 0.640426, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 3, 'text': '(Google has been mining my data for years.', 'tones': []}
# {'sentence_id': 4, 'text': "Doesn't make sense to stop now)", 'tones': [{'score': 0.542072, 'tone_id': 'anger', 'tone_name': 'Anger'}]}
# {'sentence_id': 0, 'text': 'Fitbit は \u200cGoogle の\u200c一部と\u200cなりました - Fitbit Blog', 'tones': [{'score': 0.515376, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': 'https://blog.fitbit.com/jp-2021-update/', 'tones': []}
# {'sentence_id': 2, 'text': 'https://b.hatena.ne.jp/entry/s/blog.fitbit.com/jp-2021-update/…', 'tones': []}
# {'sentence_id': 3, 'text': 'Products SMARTWATCHES Sense Versa 3 Versa 2 FITNESS TRACKERS Inspire 2 Charge 4 Inspire Family Ace 2 MORE PRODUCTS Aria Family Smart Scales Accessories Fitbit Premium Not sur…', 'tones': [{'score': 0.885055, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.606284, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 0, 'text': 'Fitbit Sense – smart zegarek z EKG.', 'tones': []}
# {'sentence_id': 1, 'text': 'Zadbasz z nim o zdrowie i aktywność sportową.', 'tones': []}
# {'sentence_id': 2, 'text': 'Jak wypadł w naszym teście?', 'tones': []}
# {'sentence_id': 0, 'text': 'Fitbit is replacing some Sense smartwatches over ECG reading issue: #AI #IoT #BigData HT: ', 'tones': [{'score': 0.681699, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 1, 'text': '@Mikequindazzi', 'tones': []}
# {'sentence_id': 2, 'text': ' https://theverge.com/2020/12/4/22152346/fitbit-sense-electrocardiogram-ecg-reading-hardware-issue-replacement…', 'tones': []}
# {'sentence_id': 0, 'text': 'Package #1 - 1100 Fitbit Clockfaces $20 - for Versa3 &amp; Sense', 'tones': []}
# {'sentence_id': 1, 'text': 'https://rb.gy/bdvzsm or https://rb.gy/wlernq', 'tones': [{'score': 0.99997, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 2, 'text': '', 'tones': []}
# {'sentence_id': 3, 'text': 'or $1 https://fouryoursucess.com', 'tones': [{'score': 0.998976, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 4, 'text': '', 'tones': []}
# {'sentence_id': 5, 'text': 'Package #2 - 1200 Fitbit clockfaces $20 - for Versa, Versa2, Versa Lite, Iconic', 'tones': []}
# {'sentence_id': 6, 'text': 'https://rb.gy/vmisj3', 'tones': []}
# {'sentence_id': 0, 'text': 'This ', 'tones': []}
# {'sentence_id': 1, 'text': '@fitbit', 'tones': []}
# {'sentence_id': 2, 'text': ' sense iOS integration  next on the bucket list, purchase a Sport band and Victor Glemaud band', 'tones': []}
# {'sentence_id': 0, 'text': 'Looking through my logged weights on my Fitbit and you can literally see a pattern of my weight dropping dramatically during/after a break up and then creeping up when I’m in relationships.', 'tones': [{'score': 0.786562, 'tone_id': 'sadness', 'tone_name': 'Sadness'}, {'score': 0.718921, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 1, 'text': 'This doesn’t make sense considering I binge eat more when I’m unhappy.', 'tones': [{'score': 0.620279, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 0, 'text': 'Fitbit couldn’t sync!!!', 'tones': []}
# {'sentence_id': 1, 'text': 'I have turned the sense on and off, I have reset my phone, I have disconnected the Bluetooth, deleted and redos load the app, what is going on?', 'tones': []}
# {'sentence_id': 2, 'text': '@FitbitUK', 'tones': []}
# {'sentence_id': 3, 'text': ' @fitbit', 'tones': []}
# {'sentence_id': 4, 'text': ' @FitbitSupport', 'tones': []}
# {'sentence_id': 0, 'text': 'Looove this Fitbit Sense clockface from ', 'tones': []}
# {'sentence_id': 1, 'text': '@renowatch', 'tones': []}
# {'sentence_id': 0, 'text': 'walking the golf course yesterday, a 19,012 step day.', 'tones': [{'score': 0.547914, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '#Fitbit #Sense', 'tones': []}
# {'sentence_id': 0, 'text': 'Lots of Wet Ass Tech up for grabs on the show over the next 2 weeks', 'tones': []}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': '- Macbook Pro', 'tones': []}
# {'sentence_id': 3, 'text': '- iPhone 12', 'tones': []}
# {'sentence_id': 4, 'text': '- 58" TV', 'tones': []}
# {'sentence_id': 5, 'text': '- Samsung Galaxy SE', 'tones': []}
# {'sentence_id': 6, 'text': '- 32GB iPad', 'tones': []}
# {'sentence_id': 7, 'text': '- Nintendo Switch + 2 Games ', 'tones': []}
# {'sentence_id': 8, 'text': '- FitBit Sense', 'tones': []}
# {'sentence_id': 9, 'text': '- Apple Watch', 'tones': []}
# {'sentence_id': 10, 'text': '- Bose Wireless Headphones', 'tones': []}
# {'sentence_id': 11, 'text': '- Amazon Smart Speaker Bundle ', 'tones': []}
# {'sentence_id': 12, 'text': '', 'tones': []}
# {'sentence_id': 13, 'text': 'Tune in from 9am to win', 'tones': [{'score': 0.75421, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 0, 'text': "Nouveau produit que je teste dès aujourd'hui !", 'tones': []}
# {'sentence_id': 1, 'text': "La montre Fitbit Sense, vous l'avez ?", 'tones': []}
# {'sentence_id': 2, 'text': 'Des avis ?', 'tones': []}
# {'sentence_id': 0, 'text': 'Senseが欲しい今日この頃。', 'tones': []}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': 'Fitbitが正式にGoogleの一部になったってよ | ギズモード・ジャパン', 'tones': []}
# {'sentence_id': 0, 'text': 'Beautiful “Pocket” #watchface #clockface by AMY ', 'tones': [{'score': 0.861312, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '@gratefulmamaof3', 'tones': []}
# {'sentence_id': 2, 'text': ' for #Fitbit #fitbitversa3 #fitbitsense #made4fitbit #fitbitversa2 #fitbitversa', 'tones': []}
# {'sentence_id': 0, 'text': 'Blue Monday but make it PINK!', 'tones': [{'score': 0.692245, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': 'We’re giving away everything you need to #StayHomeWithPLT  Including an iPad Pro, Fitbit Sense, Netflix subscription for the YEAR, a bundle of PLT goodies AND a £250 PLT voucher  To enter head over to our IG here https://bit.ly/2VNG2va', 'tones': []}
# {'sentence_id': 0, 'text': 'Upgraded to FitBit Sense.', 'tones': []}
# {'sentence_id': 1, 'text': 'Found elegant leather band on AMZN.', 'tones': [{'score': 0.842108, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 2, 'text': 'FitBit says I walked over 2,000 miles last year.', 'tones': [{'score': 0.547815, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 3, 'text': '#HealthyLiving  #Walking', 'tones': [{'score': 0.621823, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 0, 'text': 'We gave away a FitBit Sense this morning but tomorrow is the turn of the Nintendo Switch + 2 Games.', 'tones': []}
# {'sentence_id': 1, 'text': 'Win from 9am every morning on SPIN.', 'tones': [{'score': 0.700009, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.92125, 'tone_id': 'confident', 'tone_name': 'Confident'}]}
# {'sentence_id': 2, 'text': '#FullyCharged', 'tones': []}
# {'sentence_id': 0, 'text': 'I wonder if I should try again, to buy a metal mesh band for fitbit sense.', 'tones': [{'score': 0.798791, 'tone_id': 'tentative', 'tone_name': 'Tentative'}, {'score': 0.506763, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 1, 'text': 'I had one for my Versa 2 but it would pull on my arm hair and the hair on my head if my wrist got to close to my head.', 'tones': []}
# {'sentence_id': 2, 'text': "I'm sensitive to losing hair.", 'tones': [{'score': 0.749897, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 0, 'text': 'お昼休み以外動いてたみたい！', 'tones': []}
# {'sentence_id': 1, 'text': '良いことですね( ´꒳` )', 'tones': []}
# {'sentence_id': 2, 'text': '', 'tones': []}
# {'sentence_id': 3, 'text': '#fitbit', 'tones': []}
# {'sentence_id': 4, 'text': '#fitbitsense', 'tones': []}
# {'sentence_id': 5, 'text': '#fitbiterと繋がりたい', 'tones': []}
# {'sentence_id': 0, 'text': 'fitbitsenseの心拍数アラートアプリをアップデートしたら、バッテリーの持ちが良くなったような。', 'tones': []}
# {'sentence_id': 1, 'text': '#fitbit #fitbitsense #highlowheartrate #心拍数アラート', 'tones': []}
# {'sentence_id': 0, 'text': 'アンチAppleなのでapple watchの素晴らしさを知りつつ使えないでいたのだが､いつの間にあkfitbit senseがそれを上回っていることを知った｡', 'tones': []}
# {'sentence_id': 1, 'text': '後はGoogleが買収したんだからFitbit-fucking-payを駆逐して､felica決済なGooglePayを入れてくれれば腕時計ずっとつけてこなかった私でも即買いなのだけど', 'tones': [{'score': 0.781671, 'tone_id': 'anger', 'tone_name': 'Anger'}]}
# {'sentence_id': 0, 'text': 'Fitbitのレビュー書きました！', 'tones': []}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': 'スマートウォッチってどうよ！？って方、ご参考にどーぞ！', 'tones': []}
# {'sentence_id': 3, 'text': '', 'tones': []}
# {'sentence_id': 4, 'text': 'スマートウォッチ、fitbit senseを買ったので、ざっくりレビュー！', 'tones': []}
# {'sentence_id': 0, 'text': 'Haven’t been out all day but my smart watch calculates my 1409 steps is equivalent to walking 0.6 miles.', 'tones': [{'score': 0.540612, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.618451, 'tone_id': 'confident', 'tone_name': 'Confident'}]}
# {'sentence_id': 1, 'text': 'I burnt 1243 calories waking around at home.', 'tones': [{'score': 0.88939, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 2, 'text': 'My goal is to walk 5 miles per day and I have done 12% so far.', 'tones': [{'score': 0.687768, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 3, 'text': 'Love my Fitbit Sense smart watch.', 'tones': [{'score': 0.83635, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 4, 'text': 'It also shows my sleep statistics', 'tones': [{'score': 0.620279, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 0, 'text': "I've just released my first paid #fitbit watch face!", 'tones': [{'score': 0.856622, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 1, 'text': "It's a tribute to those old 'split flap' display boards - complete with animated transitions.", 'tones': []}
# {'sentence_id': 2, 'text': "See link, or search the store for 'Departure Board'.", 'tones': [{'score': 0.793846, 'tone_id': 'analytical', 'tone_name': 'Analytical'}, {'score': 0.856622, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 3, 'text': '(Sense and Versa 3) https://gallery.fitbit.com/details/55b22675-65d9-46e0-8788-51d269c2fcf0…', 'tones': []}
# {'sentence_id': 4, 'text': '$1.99', 'tones': []}
# {'sentence_id': 0, 'text': '#BonPlan  Montre Connectée - Fitbit Sense', 'tones': []}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': '265€ au lieu de 299,95€', 'tones': []}
# {'sentence_id': 3, 'text': "Cette montre connectée surveille votre santé via des outils pour le suivi cardiaque, la gestion du stress et l'évolution de la température cutanée", 'tones': []}
# {'sentence_id': 4, 'text': '', 'tones': []}
# {'sentence_id': 5, 'text': ' Pour en savoir plus  https://amzn.to/35URafT', 'tones': []}
# {'sentence_id': 0, 'text': 'Having a fitbit sense during an insurrection attempt really shines a light on what stress does to your body.', 'tones': [{'score': 0.751508, 'tone_id': 'fear', 'tone_name': 'Fear'}, {'score': 0.525007, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 1, 'text': "Let's hope my heartrate goes back down to that peaceful post-RTR level soon.", 'tones': [{'score': 0.716301, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 0, 'text': 'Waiting three weeks to get a reply from ', 'tones': []}
# {'sentence_id': 1, 'text': '@FitbitSupport', 'tones': []}
# {'sentence_id': 2, 'text': " when you can't  check your wrist for time.... #fitbit #fitbitsupport #fitbitsense", 'tones': [{'score': 0.653099, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 0, 'text': 'My kids got me a FitBit Sense for my birthday.', 'tones': [{'score': 0.643681, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': 'I’ve been jogging in my kitchen for the past 45 minutes and can’t break 9500 steps.', 'tones': []}
# {'sentence_id': 2, 'text': 'I’m assuming this will be my new normal.', 'tones': [{'score': 0.920855, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 3, 'text': 'Help.', 'tones': [{'score': 0.880435, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 0, 'text': 'Looking for a heart-rate monitoring, fitness-focused smartwatch not from Apple?  Save $68 off of this Fitbit Sense Smartwatch & get it for only $262.', 'tones': [{'score': 0.788547, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 1, 'text': '#TGSmartBuys #deals #fitness #fitbit ', 'tones': [{'score': 0.580873, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 2, 'text': 'https://buff.ly/3sKy99s', 'tones': []}
# {'sentence_id': 0, 'text': 'Fitness enthusiasts, which would you rather have?', 'tones': [{'score': 0.563367, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': 'A Fitbit sense or Apple watch', 'tones': [{'score': 0.946222, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 0, 'text': 'I’m watching TV & totally regret channel surfing cause I ended up seeing a presentation for the new ', 'tones': [{'score': 0.704333, 'tone_id': 'sadness', 'tone_name': 'Sadness'}, {'score': 0.6821, 'tone_id': 'confident', 'tone_name': 'Confident'}]}
# {'sentence_id': 1, 'text': '@fitbit', 'tones': []}
# {'sentence_id': 2, 'text': ' Sense which I totally want even more now.', 'tones': [{'score': 0.92125, 'tone_id': 'confident', 'tone_name': 'Confident'}, {'score': 0.895415, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 3, 'text': 'Aside from the obvious price that is stopping me from buying it it’s the gazillion Versa bands I have that aren’t compatible.', 'tones': [{'score': 0.579436, 'tone_id': 'confident', 'tone_name': 'Confident'}]}
# {'sentence_id': 0, 'text': 'Comenzando el año a tope!', 'tones': []}
# {'sentence_id': 1, 'text': '@ferran_rossello a comernos el 2021 gracias a @fitbitespana menudo regalazo!', 'tones': []}
# {'sentence_id': 2, 'text': '#elcarbonmola #fitbitsense #fitbitsensesmartwatch #regalodereyes en Mallorca https://instagram.com/p/CKR2XLRDx5c/?igshid=1l9fcjr33uwic…', 'tones': []}
# {'sentence_id': 0, 'text': 'Dus.... ik wil mij graag een activity tracker/smartwatch aanschaffen..', 'tones': []}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': 'Garmin/fitbit sense/Apple - zijn online precies de favorieten.', 'tones': []}
# {'sentence_id': 3, 'text': 'Iemand ervaring met 1 van deze?', 'tones': []}
# {'sentence_id': 4, 'text': 'Ik ga vooral lopen (normaal ook zwemmen en fitnessen) en wil kijken of ik voldoende slaap/rust #dtv', 'tones': []}
# {'sentence_id': 0, 'text': 'En otras noticias, ayer anduve ocupado y se me olvidó compartirles mi análisis de los ', 'tones': []}
# {'sentence_id': 1, 'text': '@fitbit', 'tones': []}
# {'sentence_id': 2, 'text': ' Sense y Versa 3. Sencillamente son los mejores en diseño y seguimiento de actividad física, pero tienen mucho de donde mejorar su software.', 'tones': []}
# {'sentence_id': 3, 'text': 'https://xataka.com.mx/p/180965', 'tones': []}
# {'sentence_id': 0, 'text': 'Had heard that the ', 'tones': []}
# {'sentence_id': 1, 'text': '@fitbit', 'tones': []}
# {'sentence_id': 2, 'text': ' #sense connectivity wasn’t the best but I didn’t think it was this bad.', 'tones': [{'score': 0.589295, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 3, 'text': 'Wont stay connected, won’t sync even after following all troubleshooting steps.', 'tones': []}
# {'sentence_id': 4, 'text': 'I hate to return it but it’s awfully expensive to be so unreliable.', 'tones': [{'score': 0.667879, 'tone_id': 'anger', 'tone_name': 'Anger'}]}
# {'sentence_id': 5, 'text': 'Please advise ', 'tones': []}
# {'sentence_id': 6, 'text': '@FitbitSupport', 'tones': []}
# {'sentence_id': 0, 'text': 'おはようございます。起きたらsenseの電池切れてたぁー', 'tones': []}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': '今朝は6:30まで寝たのに。', 'tones': []}
# {'sentence_id': 3, 'text': '', 'tones': []}
# {'sentence_id': 4, 'text': '熟睡して快適に起きたのに、睡眠スコアが６８点とかだとなえる', 'tones': []}
# ...
# {'sentence_id': 2, 'text': '今のところの候補はFitbit senseか、Garmin Venu2', 'tones': []}
# {'sentence_id': 3, 'text': '', 'tones': []}
# {'sentence_id': 4, 'text': 'みなさん、そんなに興味ないと思いますけどどっちがいいと思いますか??', 'tones': []}
# {'sentence_id': 0, 'text': 'A ver, necesito sus consejos.', 'tones': []}
# {'sentence_id': 1, 'text': 'Tengo un Fitbit versa 2 que ya está fallando el botón de inicio y me emputo cada vez que falla.', 'tones': []}
# {'sentence_id': 2, 'text': 'Estoy pensando en cambiarlo pero no sé si conviene realmente un Apple Watch 6 o un Fitbit Sense y Versa 3. Qué dice el público?', 'tones': []}
# {'sentence_id': 3, 'text': 'Cuál recomiendan?', 'tones': []}
# {'sentence_id': 0, 'text': 'Fantastic “TAC” #watchface #clockface with great AOD mode by Marc Groen ', 'tones': [{'score': 0.760488, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '@GroenMarc', 'tones': []}
# {'sentence_id': 2, 'text': ' code magic by Paul Niven ', 'tones': [{'score': 0.649387, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 3, 'text': '@NiVZ', 'tones': []}
# {'sentence_id': 4, 'text': ' for #fitbit #fitbitversa #fitbitsense #fitbitversa3 #made4fitbit with ', 'tones': []}
# {'sentence_id': 5, 'text': '@SpigenWorld', 'tones': []}
# {'sentence_id': 6, 'text': ' #spigen rugged armor pro #watchband', 'tones': [{'score': 0.523512, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 0, 'text': 'The battery in my watch died and I feel naked and have no sense of time.', 'tones': [{'score': 0.846161, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 1, 'text': 'And I can’t get to the store for a new battery until Thursday!', 'tones': []}
# {'sentence_id': 2, 'text': '(Yes I’ve got a phone and a Fitbit, but they don’t just display the time without me asking.)', 'tones': [{'score': 0.5538, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 0, 'text': '#安静時心拍数 63bpmクリア⑥', 'tones': []}
# {'sentence_id': 1, 'text': '63bpm#fitbitsense #fitbit 場所: ヒトとロボとヒト研究所\u3000【つながりあう健幸運脳遊具】開発 https://instagram.com/p/CPWcz_RHiVX/?utm_medium=twitter…', 'tones': []}
# {'sentence_id': 0, 'text': 'fitbit senseに加えて、とうとうversa3を手に入れた！しばらく使ってみる。', 'tones': []}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': '見た目はほぼ同じに見えます。', 'tones': []}
# {'sentence_id': 3, 'text': '', 'tones': []}
# {'sentence_id': 4, 'text': 'Senseはアレクサにしてるからversa3は Googleアシスタントにしてみよっと。', 'tones': []}
# {'sentence_id': 0, 'text': '#ストレス管理スコア 81 クリア⑮目標：80', 'tones': []}
# {'sentence_id': 1, 'text': '#反応性 #活動のバランス #睡眠パターン ', 'tones': []}
# {'sentence_id': 2, 'text': '#睡眠中の心拍数 #推定酸素変動量 ', 'tones': []}
# {'sentence_id': 3, 'text': '#fitbitsense #fitbit #活動量計 場所: ヒトとロボとヒト研究所\u3000【つながりあう健幸運脳遊具】開発 https://instagram.com/p/CPWcd-hHvNd/?utm_medium=twitter…', 'tones': []}
# {'sentence_id': 0, 'text': 'Stunning new “GRR AEON X700” #watchface #clockface by GRR ', 'tones': [{'score': 0.59708, 'tone_id': 'anger', 'tone_name': 'Anger'}]}
# {'sentence_id': 1, 'text': '@grrwatchfaces', 'tones': []}
# {'sentence_id': 2, 'text': ' made with http://fitface.xyz', 'tones': []}
# {'sentence_id': 3, 'text': 'for #fitbit #fitbitversa #fitbitsense #fitbitversa3 #made4fitbit with ', 'tones': []}
# {'sentence_id': 4, 'text': '@SpigenWorld', 'tones': []}
# {'sentence_id': 5, 'text': ' #spigen rugged armor pro #watchband', 'tones': [{'score': 0.523512, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 0, 'text': 'Package #1 - 1100 Fitbit Clockfaces $20 - for Versa3, Sense https://rb.gy/bdvzsm or https://rb.gy/wlernq', 'tones': [{'score': 0.822231, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': 'or $1.99 http://fouryoursucess.c...', 'tones': [{'score': 0.994446, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 0, 'text': 'Another Sharp Pic by ', 'tones': []}
# {'sentence_id': 1, 'text': '@DANdFRA', 'tones': []}
# {'sentence_id': 2, 'text': ', TAC in orange, grey, and white.', 'tones': [{'score': 0.628594, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 3, 'text': 'Always impressed with the high quality of ', 'tones': [{'score': 0.938012, 'tone_id': 'confident', 'tone_name': 'Confident'}]}
# {'sentence_id': 4, 'text': '@DANdFRA', 'tones': []}
# {'sentence_id': 5, 'text': ' photos!', 'tones': []}
# {'sentence_id': 6, 'text': 'thank you  #made4fitbit #fitbit #clockface #versa3 #fitbitsense', 'tones': []}
# {'sentence_id': 0, 'text': 'Disappointing decline in quality from ', 'tones': [{'score': 0.643218, 'tone_id': 'sadness', 'tone_name': 'Sadness'}, {'score': 0.60456, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 1, 'text': '@Apple', 'tones': []}
# {'sentence_id': 2, 'text': ' - first, iPad Pro gets stuck during update (no fix possible), then a problem with a brand new iMac’s screen, now Apple Watch stuck in boot cycle.', 'tones': [{'score': 0.682432, 'tone_id': 'sadness', 'tone_name': 'Sadness'}, {'score': 0.512886, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 3, 'text': 'I’m done.', 'tones': []}
# {'sentence_id': 4, 'text': '@Fitbit', 'tones': []}
# {'sentence_id': 5, 'text': ' sense on order.', 'tones': []}
# {'sentence_id': 6, 'text': 'Anyone have recommendations on best #Android phone?', 'tones': [{'score': 0.91961, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 0, 'text': '#安静時心拍数 63bpmクリア⑦', 'tones': []}
# {'sentence_id': 1, 'text': '63bpm#fitbitsense #fitbit 場所: 運動あそび塾『からだを使ってヒトと遊ぶ』：笑足ねっと https://instagram.com/p/CPZBAT7HisD/?utm_medium=twitter…', 'tones': []}
# {'sentence_id': 0, 'text': 'Колкото и добре да изглежда направен, все пак му взех един протектор и придоби малко rugged вид ', 'tones': []}
# {'sentence_id': 1, 'text': 'Смених и каишката със спортна, която е някакво удоволствие да я закопчаваш и разкопчаваш, сравнение със стандартната ', 'tones': []}
# {'sentence_id': 2, 'text': '#FitbitSense', 'tones': []}
# {'sentence_id': 0, 'text': '新Wear OSで今のFitbitやGalaxy Watchユーザーはどうなる？ | ギズモード・ジャパン https://gizmodo.jp/2021/05/future-of-the-partnership-between-google-samusung-and-fitbit.html…', 'tones': []}
# {'sentence_id': 1, 'text': 'fitbitはそろそろsenseの後継出してくれんかね。。', 'tones': []}
# {'sentence_id': 0, 'text': 'Awesome new “Codeboy-NextGen” #watchface #clockface by CodeboyApps ', 'tones': [{'score': 0.970035, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '@LucasKelbe', 'tones': []}
# {'sentence_id': 2, 'text': ' for #fitbit #fitbitversa #fitbitversa2 #fitbitsense #fitbitversa3 #made4fitbit with ', 'tones': []}
# {'sentence_id': 3, 'text': '@SpigenWorld', 'tones': []}
# {'sentence_id': 4, 'text': ' #spigen rugged armor pro #watchband', 'tones': [{'score': 0.523512, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 0, 'text': 'Commander now available or #FitbitVersa3 shown in  #AOD mode (always on Display).', 'tones': []}
# {'sentence_id': 1, 'text': '#fitbit #versa #steps #allwayson #clockface #fitbitsense #custom #colors #made4fitbit ', 'tones': []}
# {'sentence_id': 2, 'text': '@NiVZ', 'tones': []}
# {'sentence_id': 0, 'text': 'Awesome new “ntprOvr” #watchface #clockface with great AOD mode by ntpr ', 'tones': [{'score': 0.936319, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '@marcelsasik', 'tones': []}
# {'sentence_id': 2, 'text': ' for #fitbit #fitbitversa #fitbitsense #fitbitversa3 #made4fitbit with ', 'tones': []}
# {'sentence_id': 3, 'text': '@SpigenWorld', 'tones': []}
# {'sentence_id': 4, 'text': ' #spigen rugged armor pro #watchband', 'tones': [{'score': 0.523512, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 0, 'text': 'I think it’s weird that my ', 'tones': [{'score': 0.560424, 'tone_id': 'fear', 'tone_name': 'Fear'}, {'score': 0.842108, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 1, 'text': '@fitbit', 'tones': []}
# {'sentence_id': 2, 'text': ' sense 3 loses 10% battery life when in sleep mode and I’m sleeping…', 'tones': [{'score': 0.682387, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 0, 'text': 'When you are using a 24W ', 'tones': [{'score': 0.842108, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 1, 'text': '@AnkerOfficial', 'tones': []}
# {'sentence_id': 2, 'text': ' charger but your ', 'tones': []}
# {'sentence_id': 3, 'text': '@fitbit', 'tones': []}
# {'sentence_id': 4, 'text': ' Sense 3 says it’s charging slowly and to change outlets… I have tried 10 different outlets… I think it’s the charging cable that comes with the Fitbit…', 'tones': [{'score': 0.56572, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 0, 'text': '#安静時心拍数 63bpmクリア⑧', 'tones': []}
# {'sentence_id': 1, 'text': '63bpm#fitbitsense #fitbit 場所: ヒトとロボとヒト研究所\u3000【つながりあう健幸運脳遊具】開発 https://instagram.com/p/CPbkPVRHU9F/?utm_medium=twitter…', 'tones': []}
# {'sentence_id': 0, 'text': 'fitbit sense（スマートウォッチ）を買ってから5Kgくらい痩せたのですが、最初はベルトの一番遠い穴しか付けられんやろ！となっていたのに、最近は2つほど穴の位置が短い方に移動したんすよ。', 'tones': []}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': 'これ、痩せた！なのか、バンドが伸びた！なのかわかりかねています', 'tones': []}
# {'sentence_id': 0, 'text': 'Fantastic new “Tnoff-Linear” #watchface #clockface by TNoff Apps for #fitbit #fitbitversa #fitbitversa2 #fitbitsense #fitbitversa3 #made4fitbit with ', 'tones': [{'score': 0.775629, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '@SpigenWorld', 'tones': []}
# {'sentence_id': 2, 'text': ' #spigen rugged armor pro #watchband', 'tones': [{'score': 0.523512, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 0, 'text': 'Looking for great Father’s Day gifts?', 'tones': [{'score': 0.891426, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': 'Try GWS and http://Shop.com!', 'tones': [{'score': 0.588547, 'tone_id': 'sadness', 'tone_name': 'Sadness'}, {'score': 0.946222, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 2, 'text': 'Dad will love awesome fitness gadgets like this Fitbit Sense Carbon Strap Smart Watch.', 'tones': [{'score': 0.920635, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 3, 'text': 'Visit GWS http://Shop.com/ctracy', 'tones': []}
# {'sentence_id': 4, 'text': 'or click below.', 'tones': [{'score': 0.994446, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 5, 'text': '#ShopSaturday #FathersDay #Fitness #Fitbit', 'tones': [{'score': 0.563617, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 6, 'text': 'https://shop.com/CTRACY/Fitbit+Sense+Carbon+Strap+Smart+Watch+39mm-1865394658-p+.xhtml?credituser=R1887090…', 'tones': []}
# {'sentence_id': 0, 'text': 'Brilliant “ntprEgv” #watchface #clockface with beautiful AOD mode by ntpr ', 'tones': [{'score': 0.942605, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '@marcelsasik', 'tones': []}
# {'sentence_id': 2, 'text': ' for #fitbit #fitbitversa #fitbitsense #fitbitversa3 #made4fitbit with ', 'tones': []}
# {'sentence_id': 3, 'text': '@SpigenWorld', 'tones': []}
# {'sentence_id': 4, 'text': ' #spigen rugged armor pro #watchband #fitness #steps', 'tones': [{'score': 0.619474, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 0, 'text': 'The Fitbit Sense is pretty nifty, but some stuff is a little weird.', 'tones': [{'score': 0.933436, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 1, 'text': 'You can use Google Assistant or Amazon Alexa on it, but only Alexa will speak its answers to you.', 'tones': [{'score': 0.525007, 'tone_id': 'tentative', 'tone_name': 'Tentative'}, {'score': 0.795049, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 2, 'text': "However, Alexa doesn't support sending text messages; only Google Assistant does.", 'tones': [{'score': 0.8152, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 0, 'text': 'グーグルさま', 'tones': []}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': 'あなた様が買収したfitbit社のfitbit senseを買いますので、10月に出すと噂のあるPixelWatchは、棲み分けしてオシャレに全フリしてくださいますか？fitbit senseのように健康管理もできてしまっては私はつらいです。よろしくお願い致します。', 'tones': []}
# {'sentence_id': 0, 'text': 'Crazy “Crazy Eyes”  #watchface #clockface by Simple Mastery Apps for #fitbit #fitbitversa #fitbitversa2 #fitbitsense #fitbitversa3 #made4fitbit with ', 'tones': [{'score': 0.629302, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '@SpigenWorld', 'tones': []}
# {'sentence_id': 2, 'text': ' #spigen rugged armor pro #watchband', 'tones': [{'score': 0.523512, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}
# {'sentence_id': 0, 'text': 'Fantastic “3D clock” #watchface #clockface by Ceriboo ', 'tones': [{'score': 0.800127, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 1, 'text': '@CeriBooWP', 'tones': []}
# {'sentence_id': 2, 'text': ' for #fitbit #fitbitversa #fitbitversa2 #fitbitsense #fitbitversa3 #made4fitbit with ', 'tones': []}
# {'sentence_id': 3, 'text': '@SpigenWorld', 'tones': []}
# {'sentence_id': 4, 'text': ' #spigen rugged armor pro #watchband #steps #fitness', 'tones': [{'score': 0.619474, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 0, 'text': 'The Digilog I is about have a pretty nice update for the #Fitbit Versa 3 and Sense.', 'tones': [{'score': 0.716833, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.775166, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 1, 'text': 'The background image feature looks pretty sweet on the watch.', 'tones': [{'score': 0.83597, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.771786, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 2, 'text': '#clockface #watchface #made4fitbit', 'tones': []}
# {'sentence_id': 0, 'text': 'Digilog I is now available for #Fitbit Versa 3 & Sense!', 'tones': []}
# {'sentence_id': 1, 'text': 'https://gallery.fitbit.com/details/6975cd30-3ee1-4211-8499-df74a401566d…', 'tones': []}
# {'sentence_id': 2, 'text': '#clockface #fitness #watchface #made4fitbit', 'tones': [{'score': 0.711685, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 0, 'text': 'Package #1 - 1100 Fitbit Clockfaces $20 - for Versa3, Sense https://rb.gy/bdvzsm or https://rb.gy/wlernq', 'tones': [{'score': 0.822231, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 1, 'text': '', 'tones': []}
# {'sentence_id': 2, 'text': 'or $1.99 http://fouryoursucess.c...', 'tones': [{'score': 0.994446, 'tone_id': 'tentative', 'tone_name': 'Tentative'}]}
# {'sentence_id': 0, 'text': 'Get a Fitbit Sense for under £250 (Global)', 'tones': []}
# {'sentence_id': 1, 'text': '.', 'tones': []}
# {'sentence_id': 2, 'text': 'https://amzn.to/34AWd41', 'tones': []}
# {'sentence_id': 3, 'text': '.', 'tones': []}
# {'sentence_id': 4, 'text': '#fitbit #fitness #weightlossjourney #weightloss #fitbitversa #motivation #workout #fitfam #gym #fit #running #applewatch #fitnessmotivation #run #fitbitcharge #healthylifestyle #healthy #exercise #exercise', 'tones': [{'score': 0.919697, 'tone_id': 'joy', 'tone_name': 'Joy'}]}
# {'sentence_id': 0, 'text': 'Win a top of the line smartwatch, the Fitbit Sense ', 'tones': [{'score': 0.578743, 'tone_id': 'joy', 'tone_name': 'Joy'}, {'score': 0.895415, 'tone_id': 'analytical', 'tone_name': 'Analytical'}]}
# {'sentence_id': 1, 'text': 'Enter here  https://competitions.ie/competition/Win-a-top-of-the-line-smartwatch-the-Fitbit-Sense…', 'tones': []}
# {'sentence_id': 2, 'text': ' ', 'tones': []}
# {'sentence_id': 3, 'text': '#competitions #ireland', 'tones': []}
# {'sentence_id': 0, 'text': 'fitbit sense フィットビット センス 国内正規品 Carbon Graphite カーボングラファイト(FB512BKBK) /Lunar White ルナ ホワイト\u3000(FB512GLWT) ストレス管理、皮膚温測定などの機能 \u3000先進の健康スマートウォッチ【ブラック】Premiumサービス利用で… [楽天] https://a.r10.to/hw3B8O', 'tones': []}
# {'sentence_id': 1, 'text': '#RakutenBookmark', 'tones': []}
# {'sentence_id': 0, 'text': 'Dein innerer Akku ist fast leer?', 'tones': []}
# {'sentence_id': 1, 'text': 'Schließe für einen Moment die Augen bei einer kurzen Meditation oder einer geführten Atemübung mit der Fitbit Sense.', 'tones': [{'score': 0.603847, 'tone_id': 'sadness', 'tone_name': 'Sadness'}]}

# %% [markdown]
# ### This splits all the sentences up which makes it easier for us to work with

# %%
arr=np.array(list_Emotion)

# %%
np.unique(arr)
# Out:
# array(['Analytical', 'Anger', 'Confident', 'Fear', 'Joy', 'Sadness',
#        'Tentative'], dtype='<U10')

# %%
positive_comments=['Joy']
negative_comments=['Sadness','Anger','Fear']
neutral_comments=['Tentative','Confident','Analytical']

# %%
df['Date']=df['Timestamp'].str.split("T",expand=True)[0]

# %%
df
# Out:
#               UserScreenName          UserName                 Timestamp  \
# 0            Sandra Lafuente      @sandritalaf  2021-01-01T22:19:32.000Z
# 1     SheddingMoreThanPounds       @ThanPounds  2021-01-01T18:38:48.000Z
# 2              Cynthia Weirr        @Ngochiana  2021-01-01T14:34:59.000Z
# 3                    Heather  @Heather20358236  2021-01-01T04:08:29.000Z
# 4           のちお9割はｱｲｽで出来ています      @bow_tie_cat  2021-01-01T19:44:17.000Z
# ...                      ...               ...                       ...
# 1210              sevenones1       @sevenones1  2021-05-31T14:54:14.000Z
# 1211   The Student Tech Blog  @TheStudentTech1  2021-05-31T11:05:43.000Z
# 1212         Competitions.ie  @competitions_ie  2021-05-31T12:38:50.000Z
# 1213       Chance and Choice     @kareikitchen  2021-05-31T04:19:25.000Z
# 1214               Fitbit_DE        @Fitbit_DE  2021-05-31T08:13:06.000Z
#
#                                                    Text  \
# 0                          2021 Sin excusas#FitbitSENSE
# 1     Upped my steps today with a lovely walk by the...
# 2     Fitbit Sense drops to lowest price yet in the ...
# 3     My fitbit sense worked at first with phone cal...
# 4     やっぱりfitbit senseが無難かなー。夫が隣でもうオーダーしようとしてるから慌てて止...
# ...                                                 ...
# 1210  Package #1 - 1100 Fitbit Clockfaces $20 - for ...
# 1211  Get a Fitbit Sense for under £250 (Global)\n.\...
# 1212  Win a top of the line smartwatch, the Fitbit S...
# 1213  fitbit sense フィットビット センス 国内正規品 Carbon Graphite...
# 1214  Dein innerer Akku ist fast leer? Schließe für ...
#
#                                           Embedded_text         Emojis  \
# 0                                                   NaN              👟
# 1                                                   NaN            NaN
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4                                                   NaN  🍦 😅 🤑 💸 💸 💸 💸
# ...                                                 ...            ...
# 1210  Become healthy\nBecome a healthier, happier yo...            NaN
# 1211  Fitbit Sense Advanced Smartwatch with Tools fo...            NaN
# 1212  Win a top of the line smartwatch, the Fitbit S...        👉 💚 💚 💚
# 1213  【楽天市場】(あす楽)fitbit sense フィットビット センス 国内正規品 Carb...            NaN
# 1214                                     0:07\n88 views              🧘
#
#      Comments Likes Retweets  \
# 0           3   NaN        6
# 1         NaN   NaN        1
# 2         NaN   NaN      NaN
# 3         NaN   NaN      NaN
# 4         NaN   NaN        1
# ...       ...   ...      ...
# 1210      NaN   NaN      NaN
# 1211      NaN   NaN      NaN
# 1212      NaN   NaN      NaN
# 1213      NaN     5        6
# 1214        1     1        3
#
#                                              Image link  \
# 0     ['https://pbs.twimg.com/media/Eqre86CXIAACdYI?...
# 1     ['https://pbs.twimg.com/media/EqqsbPeXcAAcbq5?...
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1210  ['https://pbs.twimg.com/card_img/1404473934666...
# 1211  ['https://pbs.twimg.com/card_img/1404589424390...
# 1212  ['https://pbs.twimg.com/card_img/1404630448748...
# 1213  ['https://pbs.twimg.com/card_img/1404382354072...
# 1214  ['https://pbs.twimg.com/ext_tw_video_thumb/139...
#
#                                               Tweet URL        Date
# 0     https://twitter.com/sandritalaf/status/1345132...  2021-01-01
# 1     https://twitter.com/ThanPounds/status/13450770...  2021-01-01
# 2     https://twitter.com/Ngochiana/status/134501567...  2021-01-01
# 3     https://twitter.com/Heather20358236/status/134...  2021-01-01
# 4     https://twitter.com/bow_tie_cat/status/1345093...  2021-01-01
# ...                                                 ...         ...
# 1210  https://twitter.com/sevenones1/status/13993786...  2021-05-31
# 1211  https://twitter.com/TheStudentTech1/status/139...  2021-05-31
# 1212  https://twitter.com/competitions_ie/status/139...  2021-05-31
# 1213  https://twitter.com/kareikitchen/status/139921...  2021-05-31
# 1214  https://twitter.com/Fitbit_DE/status/139927774...  2021-05-31
#
# [1215 rows x 12 columns]

# %%
df['Date']=pd.to_datetime(df['Date'],errors='coerce')

# %%
monthnumber=df['Date'].dt.month
monthnumber
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1210    5
# 1211    5
# 1212    5
# 1213    5
# 1214    5
# Name: Date, Length: 1215, dtype: int64

# %%
weeknumber=df['Date'].dt.week
weeknumber
# Out:
# <ipython-input-19-5546ee6af844>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   weeknumber=df['Date'].dt.week
# 0       53
# 1       53
# 2       53
# 3       53
# 4       53
#         ..
# 1210    22
# 1211    22
# 1212    22
# 1213    22
# 1214    22
# Name: Date, Length: 1215, dtype: int64

# %%
df['Week Number']=weeknumber
df['Month Number']=monthnumber
df
# Out:
#               UserScreenName          UserName                 Timestamp  \
# 0            Sandra Lafuente      @sandritalaf  2021-01-01T22:19:32.000Z
# 1     SheddingMoreThanPounds       @ThanPounds  2021-01-01T18:38:48.000Z
# 2              Cynthia Weirr        @Ngochiana  2021-01-01T14:34:59.000Z
# 3                    Heather  @Heather20358236  2021-01-01T04:08:29.000Z
# 4           のちお9割はｱｲｽで出来ています      @bow_tie_cat  2021-01-01T19:44:17.000Z
# ...                      ...               ...                       ...
# 1210              sevenones1       @sevenones1  2021-05-31T14:54:14.000Z
# 1211   The Student Tech Blog  @TheStudentTech1  2021-05-31T11:05:43.000Z
# 1212         Competitions.ie  @competitions_ie  2021-05-31T12:38:50.000Z
# 1213       Chance and Choice     @kareikitchen  2021-05-31T04:19:25.000Z
# 1214               Fitbit_DE        @Fitbit_DE  2021-05-31T08:13:06.000Z
#
#                                                    Text  \
# 0                          2021 Sin excusas#FitbitSENSE
# 1     Upped my steps today with a lovely walk by the...
# 2     Fitbit Sense drops to lowest price yet in the ...
# 3     My fitbit sense worked at first with phone cal...
# 4     やっぱりfitbit senseが無難かなー。夫が隣でもうオーダーしようとしてるから慌てて止...
# ...                                                 ...
# 1210  Package #1 - 1100 Fitbit Clockfaces $20 - for ...
# 1211  Get a Fitbit Sense for under £250 (Global)\n.\...
# 1212  Win a top of the line smartwatch, the Fitbit S...
# 1213  fitbit sense フィットビット センス 国内正規品 Carbon Graphite...
# 1214  Dein innerer Akku ist fast leer? Schließe für ...
#
#                                           Embedded_text         Emojis  \
# 0                                                   NaN              👟
# 1                                                   NaN            NaN
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4                                                   NaN  🍦 😅 🤑 💸 💸 💸 💸
# ...                                                 ...            ...
# 1210  Become healthy\nBecome a healthier, happier yo...            NaN
# 1211  Fitbit Sense Advanced Smartwatch with Tools fo...            NaN
# 1212  Win a top of the line smartwatch, the Fitbit S...        👉 💚 💚 💚
# 1213  【楽天市場】(あす楽)fitbit sense フィットビット センス 国内正規品 Carb...            NaN
# 1214                                     0:07\n88 views              🧘
#
#      Comments Likes Retweets  \
# 0           3   NaN        6
# 1         NaN   NaN        1
# 2         NaN   NaN      NaN
# 3         NaN   NaN      NaN
# 4         NaN   NaN        1
# ...       ...   ...      ...
# 1210      NaN   NaN      NaN
# 1211      NaN   NaN      NaN
# 1212      NaN   NaN      NaN
# 1213      NaN     5        6
# 1214        1     1        3
#
#                                              Image link  \
# 0     ['https://pbs.twimg.com/media/Eqre86CXIAACdYI?...
# 1     ['https://pbs.twimg.com/media/EqqsbPeXcAAcbq5?...
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1210  ['https://pbs.twimg.com/card_img/1404473934666...
# 1211  ['https://pbs.twimg.com/card_img/1404589424390...
# 1212  ['https://pbs.twimg.com/card_img/1404630448748...
# 1213  ['https://pbs.twimg.com/card_img/1404382354072...
# 1214  ['https://pbs.twimg.com/ext_tw_video_thumb/139...
#
#                                               Tweet URL       Date  \
# 0     https://twitter.com/sandritalaf/status/1345132... 2021-01-01
# 1     https://twitter.com/ThanPounds/status/13450770... 2021-01-01
# 2     https://twitter.com/Ngochiana/status/134501567... 2021-01-01
# 3     https://twitter.com/Heather20358236/status/134... 2021-01-01
# 4     https://twitter.com/bow_tie_cat/status/1345093... 2021-01-01
# ...                                                 ...        ...
# 1210  https://twitter.com/sevenones1/status/13993786... 2021-05-31
# 1211  https://twitter.com/TheStudentTech1/status/139... 2021-05-31
# 1212  https://twitter.com/competitions_ie/status/139... 2021-05-31
# 1213  https://twitter.com/kareikitchen/status/139921... 2021-05-31
# 1214  https://twitter.com/Fitbit_DE/status/139927774... 2021-05-31
#
#       Week Number  Month Number
# 0              53             1
# 1              53             1
# 2              53             1
# 3              53             1
# 4              53             1
# ...           ...           ...
# 1210           22             5
# 1211           22             5
# 1212           22             5
# 1213           22             5
# 1214           22             5
#
# [1215 rows x 14 columns]

# %%
group=df.groupby(['Date','Week Number','Month Number'])

# %%
group.describe()
# Out:
#                                     UserScreenName                             \
#                                              count unique            top freq
# Date       Week Number Month Number
# 2021-01-01 53          1                         9      9  Ansar Mustafa    1
# 2021-01-02 53          1                        16     16  Denise Giffin    1
# 2021-01-03 53          1                         7      6        DANFRAE    2
# 2021-01-04 1           1                         9      9     Marc Groen    1
# 2021-01-05 1           1                        14     13        DANFRAE    2
# ...                                            ...    ...            ...  ...
# 2021-05-27 21          5                        10      9        DANFRAE    2
# 2021-05-28 21          5                         9      7        DANFRAE    2
# 2021-05-29 21          5                         8      6        DANFRAE    3
# 2021-05-30 21          5                         5      5         skyler    1
# 2021-05-31 22          5                         6      6     sevenones1    1
#
#                                     UserName                                \
#                                        count unique               top freq
# Date       Week Number Month Number
# 2021-01-01 53          1                   9      9      @sandritalaf    1
# 2021-01-02 53          1                  16     16      @sandritalaf    1
# 2021-01-03 53          1                   7      6          @DANdFRA    2
# 2021-01-04 1           1                   9      9        @GroenMarc    1
# 2021-01-05 1           1                  13     12          @DANdFRA    2
# ...                                      ...    ...               ...  ...
# 2021-05-27 21          5                  11     10          @DANdFRA    2
# 2021-05-28 21          5                   9      7  @Design__Pattern    2
# 2021-05-29 21          5                   8      6          @DANdFRA    3
# 2021-05-30 21          5                   5      5    @daintyxxwitch    1
# 2021-05-31 22          5                   6      6  @competitions_ie    1
#
#                                     Timestamp         ... Retweets       \
#                                         count unique  ...      top freq
# Date       Week Number Month Number                   ...
# 2021-01-01 53          1                    9      9  ...        1    2
# 2021-01-02 53          1                   16     16  ...        1    4
# 2021-01-03 53          1                    7      7  ...        5    2
# 2021-01-04 1           1                    9      9  ...        6    2
# 2021-01-05 1           1                   14     14  ...        2    2
# ...                                       ...    ...  ...      ...  ...
# 2021-05-27 21          5                   11     11  ...        5    2
# 2021-05-28 21          5                    9      9  ...        1    1
# 2021-05-29 21          5                    8      8  ...        1    2
# 2021-05-30 21          5                    5      5  ...        9    1
# 2021-05-31 22          5                    6      6  ...        9    1
#
#                                     Image link         \
#                                          count unique
# Date       Week Number Month Number
# 2021-01-01 53          1                     9      5
# 2021-01-02 53          1                    16      6
# 2021-01-03 53          1                     7      5
# 2021-01-04 1           1                     9      6
# 2021-01-05 1           1                    14      7
# ...                                        ...    ...
# 2021-05-27 21          5                    11      7
# 2021-05-28 21          5                     9      5
# 2021-05-29 21          5                     8      6
# 2021-05-30 21          5                     5      3
# 2021-05-31 22          5                     6      6
#
#                                                                                         \
#                                                                                    top
# Date       Week Number Month Number
# 2021-01-01 53          1                                                            []
# 2021-01-02 53          1                                                            []
# 2021-01-03 53          1                                                            []
# 2021-01-04 1           1                                                            []
# 2021-01-05 1           1                                                            []
# ...                                                                                ...
# 2021-05-27 21          5                                                            []
# 2021-05-28 21          5                                                            []
# 2021-05-29 21          5                                                            []
# 2021-05-30 21          5                                                            []
# 2021-05-31 22          5             ['https://pbs.twimg.com/card_img/1404382354072...
#
#                                          Tweet URL         \
#                                     freq     count unique
# Date       Week Number Month Number
# 2021-01-01 53          1               5         9      9
# 2021-01-02 53          1              11        16     16
# 2021-01-03 53          1               3         7      7
# 2021-01-04 1           1               4         9      9
# 2021-01-05 1           1               8        14     14
# ...                                  ...       ...    ...
# 2021-05-27 21          5               5        11     11
# 2021-05-28 21          5               5         9      9
# 2021-05-29 21          5               3         8      8
# 2021-05-30 21          5               3         5      5
# 2021-05-31 22          5               1         6      6
#
#                                                                                         \
#                                                                                    top
# Date       Week Number Month Number
# 2021-01-01 53          1             https://twitter.com/ThanPounds/status/13450770...
# 2021-01-02 53          1             https://twitter.com/takesukez/status/134530333...
# 2021-01-03 53          1             https://twitter.com/katelynblue19/status/13458...
# 2021-01-04 1           1             https://twitter.com/the17thman/status/13461015...
# 2021-01-05 1           1             https://twitter.com/miimi_yp/status/1346469860...
# ...                                                                                ...
# 2021-05-27 21          5             https://twitter.com/bobi1024/status/1397955398...
# 2021-05-28 21          5             https://twitter.com/Design__Pattern/status/139...
# 2021-05-29 21          5             https://twitter.com/WellnessGriffin/status/139...
# 2021-05-30 21          5             https://twitter.com/entameflash/status/1398912...
# 2021-05-31 22          5             https://twitter.com/competitions_ie/status/139...
#
#
#                                     freq
# Date       Week Number Month Number
# 2021-01-01 53          1               1
# 2021-01-02 53          1               1
# 2021-01-03 53          1               1
# 2021-01-04 1           1               1
# 2021-01-05 1           1               1
# ...                                  ...
# 2021-05-27 21          5               1
# 2021-05-28 21          5               1
# 2021-05-29 21          5               1
# 2021-05-30 21          5               1
# 2021-05-31 22          5               1
#
# [134 rows x 44 columns]

# %%
group.nth(0).reset_index().loc[0][1]
# Out:
# 53

# %%
group.nth(0).reset_index().loc[0][2]
# Out:
# 1

# %%
group.describe().reset_index()
# Out:
#           Date Week Number Month Number UserScreenName                        \
#                                                  count unique            top
# 0   2021-01-01          53            1              9      9  Ansar Mustafa
# 1   2021-01-02          53            1             16     16  Denise Giffin
# 2   2021-01-03          53            1              7      6        DANFRAE
# 3   2021-01-04           1            1              9      9     Marc Groen
# 4   2021-01-05           1            1             14     13        DANFRAE
# ..         ...         ...          ...            ...    ...            ...
# 129 2021-05-27          21            5             10      9        DANFRAE
# 130 2021-05-28          21            5              9      7        DANFRAE
# 131 2021-05-29          21            5              8      6        DANFRAE
# 132 2021-05-30          21            5              5      5         skyler
# 133 2021-05-31          22            5              6      6     sevenones1
#
#          UserName                           ... Retweets      Image link  \
#     freq    count unique               top  ...      top freq      count
# 0      1        9      9      @sandritalaf  ...        1    2          9
# 1      1       16     16      @sandritalaf  ...        1    4         16
# 2      2        7      6          @DANdFRA  ...        5    2          7
# 3      1        9      9        @GroenMarc  ...        6    2          9
# 4      2       13     12          @DANdFRA  ...        2    2         14
# ..   ...      ...    ...               ...  ...      ...  ...        ...
# 129    2       11     10          @DANdFRA  ...        5    2         11
# 130    2        9      7  @Design__Pattern  ...        1    1          9
# 131    3        8      6          @DANdFRA  ...        1    2          8
# 132    1        5      5    @daintyxxwitch  ...        9    1          5
# 133    1        6      6  @competitions_ie  ...        9    1          6
#
#                                                                    Tweet URL  \
#     unique                                                top freq     count
# 0        5                                                 []    5         9
# 1        6                                                 []   11        16
# 2        5                                                 []    3         7
# 3        6                                                 []    4         9
# 4        7                                                 []    8        14
# ..     ...                                                ...  ...       ...
# 129      7                                                 []    5        11
# 130      5                                                 []    5         9
# 131      6                                                 []    3         8
# 132      3                                                 []    3         5
# 133      6  ['https://pbs.twimg.com/card_img/1404382354072...    1         6
#
#
#     unique                                                top freq
# 0        9  https://twitter.com/ThanPounds/status/13450770...    1
# 1       16  https://twitter.com/takesukez/status/134530333...    1
# 2        7  https://twitter.com/katelynblue19/status/13458...    1
# 3        9  https://twitter.com/the17thman/status/13461015...    1
# 4       14  https://twitter.com/miimi_yp/status/1346469860...    1
# ..     ...                                                ...  ...
# 129     11  https://twitter.com/bobi1024/status/1397955398...    1
# 130      9  https://twitter.com/Design__Pattern/status/139...    1
# 131      8  https://twitter.com/WellnessGriffin/status/139...    1
# 132      5  https://twitter.com/entameflash/status/1398912...    1
# 133      6  https://twitter.com/competitions_ie/status/139...    1
#
# [134 rows x 47 columns]

# %%
dicts={}
df_new=pd.DataFrame(columns=['Date','Week','Month','Positive Comments','Negative Comments','Neutral Comments'])

# %%
len(list_Emotion)
# Out:
# 1146

# %%
for i in range(0,len(group)): 
    positive_count=0
    negative_count=0
    neutral_count=0
    for j in range(0,len(df_date)):
        try:
            if (df_date.loc[j][0:10]==str(group.nth(0).reset_index().loc[i][0])[0:10]):
                try:
                    if list_Emotion[j] in positive_comments:
                        positive_count=positive_count+1
                    if list_Emotion[j] in negative_comments:
                        negative_count=negative_count+1
                    if list_Emotion[j] in neutral_comments:
                        neutral_count=neutral_count+1
                except:
                    print("Error in list_Emotion")
        except:
            print("Error in df_date")
    dicts['Date']= group.nth(0).reset_index().loc[i][0]
    dicts['Week']= group.nth(0).reset_index().loc[i][1]
    dicts['Month']= group.nth(0).reset_index().loc[i][2]
    dicts['Positive Comments']=positive_count
    dicts['Negative Comments']=negative_count
    dicts['Neutral Comments']=neutral_count
    df_new=df_new.append(dicts,True)
# Out:
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion
# Error in list_Emotion

# %%
df_date.loc[j][0:10]
# Out:
# '2021-05-31'

# %%
df_new['Date']=df_new['Date'].dt.date

# %%
df_new
# Out:
#            Date Week Month Positive Comments Negative Comments  \
# 0    2021-01-01   53     1                 4                 1
# 1    2021-01-02   53     1                 9                 0
# 2    2021-01-03   53     1                 5                 1
# 3    2021-01-04    1     1                 1                 2
# 4    2021-01-05    1     1                 7                 2
# ..          ...  ...   ...               ...               ...
# 129  2021-05-27   21     5                 0                 0
# 130  2021-05-28   21     5                 0                 0
# 131  2021-05-29   21     5                 0                 0
# 132  2021-05-30   21     5                 0                 0
# 133  2021-05-31   22     5                 0                 0
#
#     Neutral Comments
# 0                  4
# 1                  7
# 2                  1
# 3                  6
# 4                  5
# ..               ...
# 129                0
# 130                0
# 131                0
# 132                0
# 133                0
#
# [134 rows x 6 columns]

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,5))
plt.tight_layout()
df_new.plot(x='Date', y=['Positive Comments','Negative Comments','Neutral Comments'], alpha=0.8,kind='bar')
plt.title('Comments v/s Dates')
plt.ylabel('Emotions', fontsize=12)
plt.xlabel('Date', fontsize=12)
plt.show()

# %%
week=df_new.groupby(['Week'])[['Positive Comments','Negative Comments','Neutral Comments']].sum()
week.reset_index(inplace=True)
week
# Out:
#     Week  Positive Comments  Negative Comments  Neutral Comments
# 0      1                 24                  6                38
# 1      2                 15                 11                32
# 2      3                 22                 13                42
# 3      4                 27                 15                38
# 4      5                 18                  5                39
# 5      6                 15                  7                27
# 6      7                 18                  9                24
# 7      8                 18                  8                28
# 8      9                 14                 13                36
# 9     10                 17                 23                33
# 10    11                  5                  4                 7
# 11    13                  7                  5                10
# 12    14                 17                 14                17
# 13    15                 10                 14                44
# 14    16                 24                 13                28
# 15    17                 23                  7                29
# 16    18                 17                 13                42
# 17    19                 15                 14                35
# 18    20                 19                 16                30
# 19    21                  0                  0                 0
# 20    22                  0                  0                 0
# 21    53                 18                  2                12

# %%
plt.figure(figsize=(10,5))
plt.tight_layout()
week.plot(x='Week', y=['Positive Comments','Negative Comments','Neutral Comments'], alpha=0.8,kind='bar')
plt.title('Comments v/s Week')
plt.ylabel('Emotions', fontsize=12)
plt.xlabel('Week', fontsize=12)
plt.show()

# %%
month=df_new.groupby(['Month'])[['Positive Comments','Negative Comments','Neutral Comments']].sum()
month.reset_index(inplace=True)
month
# Out:
#    Month  Positive Comments  Negative Comments  Neutral Comments
# 0      1                106                 47               162
# 1      2                 69                 29               118
# 2      3                 36                 40                76
# 3      4                 74                 51               121
# 4      5                 58                 45               114

# %%
plt.figure(figsize=(10,5))
plt.tight_layout()
month.plot(x='Month', y=['Positive Comments','Negative Comments','Neutral Comments'], alpha=0.8,kind='bar')
plt.title('Comments v/s Month')
plt.ylabel('Emotions', fontsize=12)
plt.xlabel('Month', fontsize=12)
plt.show()

# %%
all_sentences = []
for word in df_text:
    all_sentences.append(word)

# %%
all_sentences
# Out:
# ['2021 \nSin excusas\n#FitbitSENSE',
#  'Upped my steps today with a lovely walk by the coast then a slippy dog walk just now. Feeling positive until I let the little voice remind me it’s back to work in 2 days. #FitbitSENSE #WalkEveryDay2021',
#  'galaxy watch 3, garmin forerunner 245, fitbit sense? hard to choose',
#  'Fitbit Sense drops to lowest price yet in the January sales https://nigerianewsnetwork.com/fitbit-sense-drops-to-lowest-price-yet-in-the-january-sales/…',
#  "Oof! I'd say the sleep tracking on Fitbit is pretty accurate. I felt this, this morning. \n\nTime to get the day started! Have a great day! \n\n#fitbit #fitbitsense",
#  "My fitbit sense worked at first with phone calls and texts,  and then stopped I've tried everything I've seen, now it syncs but says must have an app to use this device, which I do??",
#  'アナログとデジタルをサクッと切り替える文字盤ってあんまり見かけないので試作。\n\n#fitbit\n#clockface \n#fitface\n#fitbitsense \n#analog\n#digital https://instagram.com/p/CJfcCDSg1Kh/?igshid=10p1wo2t80mxj…',
#  'やっぱりfitbit senseが無難かなー。夫が隣でもうオーダーしようとしてるから慌てて止めたけど\nsurface  proもオーダーしたばっかだけど\n普段ケチケチしてるくせに1度使い出すと止まらなくなるやっかいな性格',
#  'fitbit senseに不満はないのだが、ストレス測る機能がいまいちわからない。',
#  'Fitbit Sense cae al precio de venta más bajo de enero',
#  'Fitbit Sense drops to lowest price yet in the January sales https://bibarud.com/fitbit-sense-drops-to-lowest-price-yet-in-the-january-sales/…',
#  'New post: Fitbit Sense drops to lowest price yet in the January sales']

# %%
lines = list()
for line in all_sentences:    
    words = line.split()
    for w in words: 
       lines.append(w)


print(lines)
# Out:
# ['2021', 'Sin', 'excusas', '#FitbitSENSE', 'Upped', 'my', 'steps', 'today', 'with', 'a', 'lovely', 'walk', 'by', 'the', 'coast', 'then', 'a', 'slippy', 'dog', 'walk', 'just', 'now.', 'Feeling', 'positive', 'until', 'I', 'let', 'the', 'little', 'voice', 'remind', 'me', 'it’s', 'back', 'to', 'work', 'in', '2', 'days.', '#FitbitSENSE', '#WalkEveryDay2021', 'galaxy', 'watch', '3,', 'garmin', 'forerunner', '245,', 'fitbit', 'sense?', 'hard', 'to', 'choose', 'Fitbit', 'Sense', 'drops', 'to', 'lowest', 'price', 'yet', 'in', 'the', 'January', 'sales', 'https://nigerianewsnetwork.com/fitbit-sense-drops-to-lowest-price-yet-in-the-january-sales/…', 'Oof!', "I'd", 'say', 'the', 'sleep', 'tracking', 'on', 'Fitbit', 'is', 'pretty', 'accurate.', 'I', 'felt', 'this,', 'this', 'morning.', 'Time', 'to', 'get', 'the', 'day', 'started!', 'Have', 'a', 'great', 'day!', '#fitbit', '#fitbitsense', 'My', 'fitbit', 'sense', 'worked', 'at', 'first', 'with', 'phone', 'calls', 'and', 'texts,', 'and', 'then', 'stopped', "I've", 'tried', 'everything', "I've", 'seen,', 'now', 'it', 'syncs', 'but', 'says', 'must', 'have', 'an', 'app', 'to', 'use', 'this', 'device,', 'which', 'I', 'do??', 'アナログとデジタルをサクッと切り替える文字盤ってあんまり見かけないので試作。', '#fitbit', '#clockface', '#fitface', '#fitbitsense', '#analog', '#digital', 'https://instagram.com/p/CJfcCDSg1Kh/?igshid=10p1wo2t80mxj…', 'やっぱりfitbit', 'senseが無難かなー。夫が隣でもうオーダーしようとしてるから慌てて止めたけど', 'surface', 'proもオーダーしたばっかだけど', '普段ケチケチしてるくせに1度使い出すと止まらなくなるやっかいな性格', 'fitbit', 'senseに不満はないのだが、ストレス測る機能がいまいちわからない。', 'Fitbit', 'Sense', 'cae', 'al', 'precio', 'de', 'venta', 'más', 'bajo', 'de', 'enero', 'Fitbit', 'Sense', 'drops', 'to', 'lowest', 'price', 'yet', 'in', 'the', 'January', 'sales', 'https://bibarud.com/fitbit-sense-drops-to-lowest-price-yet-in-the-january-sales/…', 'New', 'post:', 'Fitbit', 'Sense', 'drops', 'to', 'lowest', 'price', 'yet', 'in', 'the', 'January', 'sales']

# %% [markdown]
# ### Removing Punctuation

# %%
lines = [re.sub(r'[^A-Za-z0-9]+', '', x) for x in lines]

lines

lines2 = []

for word in lines:
    if word != '':
        lines2.append(word)

# %%
lines2
# Out:
# ['2021',
#  'Sin',
#  'excusas',
#  'FitbitSENSE',
#  'Upped',
#  'my',
#  'steps',
#  'today',
#  'with',
#  'a',
#  'lovely',
#  'walk',
#  'by',
#  'the',
#  'coast',
#  'then',
#  'a',
#  'slippy',
#  'dog',
#  'walk',
#  'just',
#  'now',
#  'Feeling',
#  'positive',
#  'until',
#  'I',
#  'let',
#  'the',
#  'little',
#  'voice',
#  'remind',
#  'me',
#  'its',
#  'back',
#  'to',
#  'work',
#  'in',
#  '2',
#  'days',
#  'FitbitSENSE',
#  'WalkEveryDay2021',
#  'galaxy',
#  'watch',
#  '3',
#  'garmin',
#  'forerunner',
#  '245',
#  'fitbit',
#  'sense',
#  'hard',
#  'to',
#  'choose',
#  'Fitbit',
#  'Sense',
#  'drops',
#  'to',
#  'lowest',
#  'price',
#  'yet',
#  'in',
#  'the',
#  'January',
#  'sales',
#  'httpsnigerianewsnetworkcomfitbitsensedropstolowestpriceyetinthejanuarysales',
#  'Oof',
#  'Id',
#  'say',
#  'the',
#  'sleep',
#  'tracking',
#  'on',
#  'Fitbit',
#  'is',
#  'pretty',
#  'accurate',
#  'I',
#  'felt',
#  'this',
#  'this',
#  'morning',
#  'Time',
#  'to',
#  'get',
#  'the',
#  'day',
#  'started',
#  'Have',
#  'a',
#  'great',
#  'day',
#  'fitbit',
#  'fitbitsense',
#  'My',
#  'fitbit',
#  'sense',
#  'worked',
#  'at',
#  'first',
#  'with',
#  'phone',
#  'calls',
#  'and',
#  'texts',
#  'and',
#  'then',
#  'stopped',
#  'Ive',
#  'tried',
#  'everything',
#  'Ive',
#  'seen',
#  'now',
#  'it',
#  'syncs',
#  'but',
#  'says',
#  'must',
#  'have',
#  'an',
#  'app',
#  'to',
#  'use',
#  'this',
#  'device',
#  'which',
#  'I',
#  'do',
#  'fitbit',
#  'clockface',
#  'fitface',
#  'fitbitsense',
#  'analog',
#  'digital',
#  'httpsinstagramcompCJfcCDSg1Khigshid10p1wo2t80mxj',
#  'fitbit',
#  'sense',
#  'surface',
#  'pro',
#  '1',
#  'fitbit',
#  'sense',
#  'Fitbit',
#  'Sense',
#  'cae',
#  'al',
#  'precio',
#  'de',
#  'venta',
#  'ms',
#  'bajo',
#  'de',
#  'enero',
#  'Fitbit',
#  'Sense',
#  'drops',
#  'to',
#  'lowest',
#  'price',
#  'yet',
#  'in',
#  'the',
#  'January',
#  'sales',
#  'httpsbibarudcomfitbitsensedropstolowestpriceyetinthejanuarysales',
#  'New',
#  'post',
#  'Fitbit',
#  'Sense',
#  'drops',
#  'to',
#  'lowest',
#  'price',
#  'yet',
#  'in',
#  'the',
#  'January',
#  'sales']

# %% [markdown]
# ### This is stemming the words to their root

# %%
from nltk.stem.snowball import SnowballStemmer

# The Snowball Stemmer requires that you pass a language parameter
s_stemmer = SnowballStemmer(language='english')

stem = []
for word in lines2:
    stem.append(s_stemmer.stem(word))
    
stem
# Out:
# ['2021',
#  'sin',
#  'excusa',
#  'fitbitsens',
#  'up',
#  'my',
#  'step',
#  'today',
#  'with',
#  'a',
#  'love',
#  'walk',
#  'by',
#  'the',
#  'coast',
#  'then',
#  'a',
#  'slippi',
#  'dog',
#  'walk',
#  'just',
#  'now',
#  'feel',
#  'posit',
#  'until',
#  'i',
#  'let',
#  'the',
#  'littl',
#  'voic',
#  'remind',
#  'me',
#  'it',
#  'back',
#  'to',
#  'work',
#  'in',
#  '2',
#  'day',
#  'fitbitsens',
#  'walkeveryday2021',
#  'galaxi',
#  'watch',
#  '3',
#  'garmin',
#  'forerunn',
#  '245',
#  'fitbit',
#  'sens',
#  'hard',
#  'to',
#  'choos',
#  'fitbit',
#  'sens',
#  'drop',
#  'to',
#  'lowest',
#  'price',
#  'yet',
#  'in',
#  'the',
#  'januari',
#  'sale',
#  'httpsnigerianewsnetworkcomfitbitsensedropstolowestpriceyetinthejanuarysal',
#  'oof',
#  'id',
#  'say',
#  'the',
#  'sleep',
#  'track',
#  'on',
#  'fitbit',
#  'is',
#  'pretti',
#  'accur',
#  'i',
#  'felt',
#  'this',
#  'this',
#  'morn',
#  'time',
#  'to',
#  'get',
#  'the',
#  'day',
#  'start',
#  'have',
#  'a',
#  'great',
#  'day',
#  'fitbit',
#  'fitbitsens',
#  'my',
#  'fitbit',
#  'sens',
#  'work',
#  'at',
#  'first',
#  'with',
#  'phone',
#  'call',
#  'and',
#  'text',
#  'and',
#  'then',
#  'stop',
#  'ive',
#  'tri',
#  'everyth',
#  'ive',
#  'seen',
#  'now',
#  'it',
#  'sync',
#  'but',
#  'say',
#  'must',
#  'have',
#  'an',
#  'app',
#  'to',
#  'use',
#  'this',
#  'devic',
#  'which',
#  'i',
#  'do',
#  'fitbit',
#  'clockfac',
#  'fitfac',
#  'fitbitsens',
#  'analog',
#  'digit',
#  'httpsinstagramcompcjfccdsg1khigshid10p1wo2t80mxj',
#  'fitbit',
#  'sens',
#  'surfac',
#  'pro',
#  '1',
#  'fitbit',
#  'sens',
#  'fitbit',
#  'sens',
#  'cae',
#  'al',
#  'precio',
#  'de',
#  'venta',
#  'ms',
#  'bajo',
#  'de',
#  'enero',
#  'fitbit',
#  'sens',
#  'drop',
#  'to',
#  'lowest',
#  'price',
#  'yet',
#  'in',
#  'the',
#  'januari',
#  'sale',
#  'httpsbibarudcomfitbitsensedropstolowestpriceyetinthejanuarysal',
#  'new',
#  'post',
#  'fitbit',
#  'sens',
#  'drop',
#  'to',
#  'lowest',
#  'price',
#  'yet',
#  'in',
#  'the',
#  'januari',
#  'sale']

# %% [markdown]
# ### Removing all Stop Words

# %%
stem2 = []

for word in stem:
    if word not in nlp.Defaults.stop_words:
        stem2.append(word)

stem2
# Out:
# ['2021',
#  'sin',
#  'excusa',
#  'fitbitsens',
#  'step',
#  'today',
#  'love',
#  'walk',
#  'coast',
#  'slippi',
#  'dog',
#  'walk',
#  'feel',
#  'posit',
#  'let',
#  'littl',
#  'voic',
#  'remind',
#  'work',
#  '2',
#  'day',
#  'fitbitsens',
#  'walkeveryday2021',
#  'galaxi',
#  'watch',
#  '3',
#  'garmin',
#  'forerunn',
#  '245',
#  'fitbit',
#  'sens',
#  'hard',
#  'choos',
#  'fitbit',
#  'sens',
#  'drop',
#  'lowest',
#  'price',
#  'januari',
#  'sale',
#  'httpsnigerianewsnetworkcomfitbitsensedropstolowestpriceyetinthejanuarysal',
#  'oof',
#  'id',
#  'sleep',
#  'track',
#  'fitbit',
#  'pretti',
#  'accur',
#  'felt',
#  'morn',
#  'time',
#  'day',
#  'start',
#  'great',
#  'day',
#  'fitbit',
#  'fitbitsens',
#  'fitbit',
#  'sens',
#  'work',
#  'phone',
#  'text',
#  'stop',
#  'ive',
#  'tri',
#  'everyth',
#  'ive',
#  'seen',
#  'sync',
#  'app',
#  'use',
#  'devic',
#  'fitbit',
#  'clockfac',
#  'fitfac',
#  'fitbitsens',
#  'analog',
#  'digit',
#  'httpsinstagramcompcjfccdsg1khigshid10p1wo2t80mxj',
#  'fitbit',
#  'sens',
#  'surfac',
#  'pro',
#  '1',
#  'fitbit',
#  'sens',
#  'fitbit',
#  'sens',
#  'cae',
#  'al',
#  'precio',
#  'de',
#  'venta',
#  'ms',
#  'bajo',
#  'de',
#  'enero',
#  'fitbit',
#  'sens',
#  'drop',
#  'lowest',
#  'price',
#  'januari',
#  'sale',
#  'httpsbibarudcomfitbitsensedropstolowestpriceyetinthejanuarysal',
#  'new',
#  'post',
#  'fitbit',
#  'sens',
#  'drop',
#  'lowest',
#  'price',
#  'januari',
#  'sale']

# %%
df_cleansed = pd.DataFrame(stem2)

df_cleansed = df_cleansed[0].value_counts()

# %%
df_cleansed
# Out:
# fitbit                                                                       11
# sens                                                                          8
# fitbitsens                                                                    4
# drop                                                                          3
# lowest                                                                        3
# sale                                                                          3
# day                                                                           3
# price                                                                         3
# januari                                                                       3
# work                                                                          2
# de                                                                            2
# ive                                                                           2
# walk                                                                          2
# surfac                                                                        1
# seen                                                                          1
# sleep                                                                         1
# httpsbibarudcomfitbitsensedropstolowestpriceyetinthejanuarysal                1
# hard                                                                          1
# garmin                                                                        1
# digit                                                                         1
# choos                                                                         1
# felt                                                                          1
# voic                                                                          1
# analog                                                                        1
# app                                                                           1
# httpsnigerianewsnetworkcomfitbitsensedropstolowestpriceyetinthejanuarysal     1
# walkeveryday2021                                                              1
# posit                                                                         1
# post                                                                          1
# littl                                                                         1
# let                                                                           1
# dog                                                                           1
# new                                                                           1
# use                                                                           1
# clockfac                                                                      1
# fitfac                                                                        1
# stop                                                                          1
# pretti                                                                        1
# accur                                                                         1
# httpsinstagramcompcjfccdsg1khigshid10p1wo2t80mxj                              1
# devic                                                                         1
# precio                                                                        1
# remind                                                                        1
# bajo                                                                          1
# cae                                                                           1
# text                                                                          1
# start                                                                         1
# slippi                                                                        1
# love                                                                          1
# venta                                                                         1
# great                                                                         1
# excusa                                                                        1
# id                                                                            1
# today                                                                         1
# ms                                                                            1
# feel                                                                          1
# 2021                                                                          1
# everyth                                                                       1
# 3                                                                             1
# sin                                                                           1
# forerunn                                                                      1
# galaxi                                                                        1
# watch                                                                         1
# coast                                                                         1
# enero                                                                         1
# phone                                                                         1
# morn                                                                          1
# 2                                                                             1
# 1                                                                             1
# step                                                                          1
# tri                                                                           1
# 245                                                                           1
# al                                                                            1
# track                                                                         1
# oof                                                                           1
# time                                                                          1
# sync                                                                          1
# pro                                                                           1
# Name: 0, dtype: int64

# %%
# df=df[1:] # removing the first word friquency

# %% [markdown]
# ### This will give frequencies of our words

# %%
from nltk.probability import FreqDist

freqdoctor = FreqDist()

for words in df:
    freqdoctor[words] += 1

freqdoctor
# Out:
# FreqDist({'UserScreenName': 1, 'UserName': 1, 'Timestamp': 1, 'Text': 1, 'Embedded_text': 1, 'Emojis': 1, 'Comments': 1, 'Likes': 1, 'Retweets': 1, 'Image link': 1, ...})

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#This is a simple plot that shows the top 30 words being used

df_emotion = pd.DataFrame(list_Emotion)[0].value_counts()
plt.figure(figsize=(10,5))
sns.barplot(df_emotion.values, df_emotion.index, alpha=0.8)
plt.title('Top Emotions')
plt.ylabel('Emotions', fontsize=12)
plt.xlabel('Count of Emotion', fontsize=12)
plt.show()

# %%
df_cleansed.sum()
# Out:
# 114

# %%
#This is a simple plot that shows the top 30 words being used
#df.plot(30)

df_plot = df_cleansed[:20,]
plt.figure(figsize=(10,5))
sns.barplot(df_plot.values, df_plot.index, alpha=0.8, palette=("Oranges"))
plt.title('Top Words Overall')
plt.ylabel('Word from Tweet', fontsize=12)
plt.xlabel('Count of Words', fontsize=12)
plt.show()

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
def show_ents(doc):
    if doc.ents:
        for ent in doc.ents:
            print(ent.text + ' - ' + ent.label_ + ' - ' + str(spacy.explain(ent.label_)))

# %%
str1 = " " 
stem2 = str1.join(lines2)

stem2 = nlp(stem2)

label = [(X.text, X.label_) for X in stem2.ents]

df6 = pd.DataFrame(label, columns = ['Word','Entity'])

df7 = df6.where(df6['Entity'] == 'ORG')

df7 = df7['Word'].value_counts()

# %%
df_plot = df7[:20,]
plt.figure(figsize=(10,5))
sns.barplot(df_plot.values, df_plot.index, alpha=0.8, palette=("Oranges"))
plt.title('Top Organizations Mentioned')
plt.ylabel('Word from Tweet', fontsize=12)
plt.xlabel('Count of Words', fontsize=12)
plt.show()

# %%
str1 = " " 
stem2 = str1.join(lines2)

stem2 = nlp(stem2)

label = [(X.text, X.label_) for X in stem2.ents]

df10 = pd.DataFrame(label, columns = ['Word','Entity'])

df10 = df10.where(df10['Entity'] == 'PERSON')

df11 = df10['Word'].value_counts()
